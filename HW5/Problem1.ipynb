# %% [markdown]
# <a href="https://colab.research.google.com/github/autumnWindigo/GenAI/blob/main/HW5/Problem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses

# %% [markdown]
# # Params

# %%
VOCAB_SIZE = 10000
MAX_LEN = 300
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 32
EPOCHS = 25

# %% [markdown]
# # Download and Condense Data from gutenberg

# %%
import re
import requests

all_text = ""

urls = [
        "https://www.gutenberg.org/cache/epub/1533/pg1533.txt",
        "https://www.gutenberg.org/cache/epub/1531/pg1531.txt",
        "https://www.gutenberg.org/cache/epub/1524/pg1524.txt",
        "https://www.gutenberg.org/cache/epub/1526/pg1526.txt",
        "https://www.gutenberg.org/cache/epub/1514/pg1514.txt",
        ]

# Needs to be run individually on downloaded plays
def clean_text_before_act(text):
    # Remove everything before the first "ACT"
    # Each play has two "ACT" after which the text follows
    match_start = re.search(r'(ACT I\s)', text)
    if match_start:
        text = text.split(match_start.group(0), 1)[1]
    return text

for url in urls:
  response = requests.get(url)
  text = response.text

  # Regex to clean the junk and notes from the top
  match_start = re.search(r'\*\*\* START OF THE PROJECT GUTENBERG EBOOK.*\*\*\*', text)

  # Split at the match and only take what's after (the actual ebook)
  if match_start:
    text = text.split(match_start.group(0), 1)[1]

  # Split at the match and only take before their legal stuff at the end
  match_end = re.search(r'\*\*\* END OF THE PROJECT GUTENBERG EBOOK.*\*\*\*', text)
  if match_end:
    text = text.split(match_end.group(0), 1)[0]

  text = clean_text_before_act(text)
  text = clean_text_before_act(text)

  # Add all
  all_text += text + "\n\n"

# Save to file
with open("combined_shakespeare.txt", "w", encoding="utf-8") as file:
    file.write(all_text)

# %% [markdown]
# # Loading Data

# %%
with open("combined_shakespeare.txt", "r", encoding="utf-8") as file:
    text = file.read()

# %% [markdown]
# # Tokenize Data

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.11.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain)
#   Downloading langchain_core-0.3.19-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.144-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading propcache-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 2.1 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.15->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 2.9 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Downloading langchain-0.3.7-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.5 MB/s eta 0:00:00
# Downloading aiohttp-3.11.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.2 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_core-0.3.19-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 26.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.144-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.1/310.1 kB 16.7 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.3 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.9/241.9 kB 12.1 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.5/599.5 kB 29.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.0 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 9.2 MB/s eta 0:00:00
# Downloading orjson-3.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 10.6 MB/s eta 0:00:00
# Downloading propcache-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.9/208.9 kB 15.8 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.6 MB/s eta 0:00:00
# Downloading yarl-1.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.4/319.4 kB 24.1 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: propcache, orjson, multidict, jsonpointer, h11, greenlet, frozenlist, async-timeout, aiohappyeyeballs, yarl, SQLAlchemy, requests-toolbelt, jsonpatch, httpcore, aiosignal, httpx, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.3 aiohttp-3.11.7 aiosignal-1.3.1 async-timeout-4.0.3 frozenlist-1.5.0 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.7 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.7 langchain-core-0.3.19 langchain-text-splitters-0.3.2 langsmith-0.1.144 multidict-6.1.0 orjson-3.10.11 propcache-0.2.0 requests-toolbelt-1.0.0 yarl-1.18.0

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# We need to do a few things to make this text not awful:
# 1) Pad punctiation because LSTM models are awful if you don't
# 2) Remove stage directions & act stuff since it will confuse and are not useful.
# 3) Set to lowercase so it has less vocab to consider
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import matplotlib.pyplot as plt

# STEP 1
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)  # Remove multiple spaces
    return s

# STEP 2 & 3
def clean_text(text):
    text = re.sub(r'(act [ivxlcdm]+|scene [ivxlcdm]*)', '', text)  # Remove act & scene markers
    text = re.sub(r'\[.*?\]', '', text)  # Remove stage directions and related
    text = re.sub(r'\n+', ' <newline> ', text) # Replace new line with token to preserve structure
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space

    # Remove single word speaker introductions
    # Some classic characters like "second clown" are too hard to distinguish from short lines
    text = re.sub(r'<newline> [A-Za-z]+ \. <newline>', '', text)
    text = re.sub(r'\s+', ' ', text)  # Fix awkward speaker removal
    return text.strip() # Strip just normal stuff

text = pad_punctuation(text).lower()
text = clean_text(text)

# Chunk to our max length
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=MAX_LEN,
    chunk_overlap=1,
    length_function=len,
)

chunks = text_splitter.split_text(text) # Split into MAX_LEN chunks for LSTM to read easy

text = list(filter(None, chunks)) # Filter any funky chunks

# Happy with this
print(text)

# %%
# Create a vectorisation layer
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# Convert for tensorflow and batch
text_ds = (
    tf.data.Dataset.from_tensor_slices(text)
    .batch(BATCH_SIZE)
    .shuffle(1000)
)


# Adapt the layer to the training set
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()

# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: ,
# 3: <newline>
# 4: .
# 5: the
# 6: and
# 7: i
# 8: to
# 9: of

# %%
def prepare_inputs(text):
    tokenized_sentences = vectorize_layer(text)

    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]

    return x, y

train_ds = text_ds.map(prepare_inputs)

# %% [markdown]
# # Build The LSTM

# %%
inputs = layers.Input(shape=(None,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.LSTM(128, return_sequences=True, dropout=0.2)(x)  # Dropout to avoid overfitting <newline>
x = layers.LSTM(128, return_sequences=True, dropout=0.2)(x)  # Also 128 units
x = layers.LSTM(128, return_sequences=True, dropout=0.2)(x)
outputs = layers.Dense(VOCAB_SIZE, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, None)]            0
#
#  embedding_4 (Embedding)     (None, None, 100)         1000000
#
#  lstm_7 (LSTM)               (None, None, 128)         117248
#
#  lstm_8 (LSTM)               (None, None, 128)         131584
#
#  lstm_9 (LSTM)               (None, None, 128)         131584
#
#  dense_4 (Dense)             (None, None, 10000)       1290000
#
# =================================================================
# Total params: 2670416 (10.19 MB)
# Trainable params: 2670416 (10.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training LSTM

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Create a TextGenerator checkpoint
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("Now is the winter of our discontent", max_tokens=100, temperature=1.0)

# %%
text_generator = TextGenerator(vocab)

lstm.fit(train_ds, epochs=EPOCHS, callbacks=[text_generator])
# Out:
# Epoch 1/25
# 77/77 [==============================] - ETA: 0s - loss: 3.5985
# generated text:
# Now is the winter of our discontent
#
# 77/77 [==============================] - 67s 805ms/step - loss: 3.5985
# Epoch 2/25
# 77/77 [==============================] - ETA: 0s - loss: 1.6623
# generated text:
# Now is the winter of our discontent
#
# 77/77 [==============================] - 61s 795ms/step - loss: 1.6623
# Epoch 3/25
# 77/77 [==============================] - ETA: 0s - loss: 1.4095
# generated text:
# Now is the winter of our discontent <newline> <newline> charm i sad , other - pare to me them all and a all odours excepted habits
#
# 77/77 [==============================] - 64s 827ms/step - loss: 1.4095
# Epoch 4/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2695
# generated text:
# Now is the winter of our discontent may o thee ; hate moon . knacks thrown lady make , cursed her implorators you customary ! , to
#
# 77/77 [==============================] - 63s 811ms/step - loss: 1.2695
# Epoch 5/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2491
# generated text:
# Now is the winter of our discontent ,
#
# 77/77 [==============================] - 61s 795ms/step - loss: 1.2491
# Epoch 6/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2309
# generated text:
# Now is the winter of our discontent with thrift , la our with the . whose curses jest for up of me thought let and , saying poor of but ? they if of listen this ? the passed goodness , state ; threw ? what’s so what <newline> palace enter the obey
#
# 77/77 [==============================] - 65s 847ms/step - loss: 1.2309
# Epoch 7/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2262
# generated text:
# Now is the winter of our discontent , thank ? bed and <newline> fabian grown but reserve in <newline> <newline> thy general first you him both the ; hermia hurt . to lady - mercy i , and had the kind <newline> , out outward ? players hare the long
#
# 77/77 [==============================] - 64s 832ms/step - loss: 1.2262
# Epoch 8/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2212
# generated text:
# Now is the winter of our discontent , to from betimes pale it world’s . are and bow pray be her when true mad , draw desk himself invention at rank beautiful <newline> and shall something as there handsome , the his monstrous part the perdition friends meed . made true my ? not players limed lands in lady
#
# 77/77 [==============================] - 66s 855ms/step - loss: 1.2212
# Epoch 9/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2156
# generated text:
# Now is the winter of our discontent oberon mad that and , for and sure you — are ? please potent device speech . a it ; be <newline> think tyrant first keep judgements choice i thorns death keen process , are that him speak heraldry <newline> fury of knocking gore , ever , away then
#
# 77/77 [==============================] - 65s 845ms/step - loss: 1.2156
# Epoch 10/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2097
# generated text:
# Now is the winter of our discontent and unity if haste go needs him lie ’haviour <newline> o but afraid , it i’ immediate as , cup we her and very heavy more . trick and note then , a you to the i o in has known terms i deny payment chair of
#
# 77/77 [==============================] - 65s 845ms/step - loss: 1.2097
# Epoch 11/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2054
# generated text:
# Now is the winter of our discontent notable well night on’t <newline> by see were to - action the , . lead . i ; showing <newline> many the will and of precepts , i lord <newline> have love hath . ‘let keep save gore i ’tis better <newline> with my farewell up <newline> cesario . heart my
#
# 77/77 [==============================] - 66s 853ms/step - loss: 1.2054
# Epoch 12/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2001
# generated text:
# Now is the winter of our discontent ? thy verses thank go <newline> . wrath ; <newline> vanished , , , good <newline> so . fortunes is see what whose am give <newline> thou the a <newline> , , when wherewith by you <newline> procreants monster get makes sugar <newline> . take , , his <newline> <newline> a <newline>
#
# 77/77 [==============================] - 65s 850ms/step - loss: 1.2001
# Epoch 13/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2002
# generated text:
# Now is the winter of our discontent . you . <newline> i and began saying thought , that his , olivia ; it <newline> hear a lord had bodies the . <newline> this me hangers , , fife equivocate heaven’s be not must some my . letters . . his sorrow sleep cassio monster and little me sleep a screen’d
#
# 77/77 [==============================] - 66s 857ms/step - loss: 1.2002
# Epoch 14/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1984
# generated text:
# Now is the winter of our discontent of the trophies . . construction lord the a mongrels . to so must , hath i ocular some that , war but the a oath by , of apt sound we such <newline> forbid this ? , : fall with to i’ll gentleman countenance , was <newline> look hang
#
# 77/77 [==============================] - 65s 844ms/step - loss: 1.1984
# Epoch 15/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1977
# generated text:
# Now is the winter of our discontent thou thoughts you poisons , to a siward i more know than , is in , . virtue thy : ignorance play one and <newline> by i regards ; thy . until musician into worth , : royal nearly i of . be , . awhile first , ,
#
# 77/77 [==============================] - 65s 842ms/step - loss: 1.1977
# Epoch 16/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1947
# generated text:
# Now is the winter of our discontent <newline> let less contagious false you to she thou my and shall and . , <newline> , , <newline> i <newline> ? this takes well as good with thou : a and <newline> king conceits friend is in him matter not in fortune’s thy not . and a the clear
#
# 77/77 [==============================] - 66s 852ms/step - loss: 1.1947
# Epoch 17/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1950
# generated text:
# Now is the winter of our discontent . side my , enter seem ; he’s , my command . , breast you though by heart my enter you upon . . of and niece . can . <newline> fools the . , bounteous , let <newline> love or this i terms slay <newline> god finish’d , , ? him our given abhor find minds
#
# 77/77 [==============================] - 66s 858ms/step - loss: 1.1950
# Epoch 18/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1914
# generated text:
# Now is the winter of our discontent . tell my your what root your this ; me step . . i this , barren <newline> occasion i i’ll her gull have world <newline> good the . within leave . and sir your there . we house much <newline> this thou new pure sister my a , offence to i’ but
#
# 77/77 [==============================] - 65s 848ms/step - loss: 1.1914
# Epoch 19/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1925
# generated text:
# Now is the winter of our discontent late him keep do no , how heat that and for . as my and <newline> all his not his ? the sunny , study nunnery is husbandry or faith along of down whose <newline> , graveness plague thanks me if neptune’s fury and norman ; . <newline> ! as when and region act have
#
# 77/77 [==============================] - 66s 853ms/step - loss: 1.1925
# Epoch 20/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1925
# generated text:
# Now is the winter of our discontent alms . he , <newline> ! things <newline> such same drunk the roundel assigns had what : , , wit’s and , parts on horatio why but , . cause highly beef a you my remorse kiss . outward <newline> ,
#
# 77/77 [==============================] - 65s 841ms/step - loss: 1.1925
# Epoch 21/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1875
# generated text:
# Now is the winter of our discontent ! who our <newline> or would king assigns heavens <newline> i is <newline> come , you ; have how the my under upon youth , . not could it noble his ; , , . as are best gratillity . barefac’d world , good ambition smoothness ? <newline> , thine all this , . ;
#
# 77/77 [==============================] - 67s 866ms/step - loss: 1.1875
# Epoch 22/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1892
# generated text:
# Now is the winter of our discontent ah comfort lord cubiculo born are that with none ay <newline> make to done now , but not rights <newline> ’ love <newline> come the that o from put it strange . sinews her so it : to all polonius is’t , lord , schooling , play hast have
#
# 77/77 [==============================] - 66s 856ms/step - loss: 1.1892
# Epoch 23/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1870
# generated text:
# Now is the winter of our discontent it , , opinion the horatio with more [ as a ! on we the let . now guard <newline> good and let not faith , thyme or the no to of part then me bred as should <newline> in that even roderigo will on carry the of tables strangely entertainment . sadly
#
# 77/77 [==============================] - 65s 847ms/step - loss: 1.1870
# Epoch 24/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1841
# generated text:
# Now is the winter of our discontent see your prov’d help to way in lose and of what we rat but crowner tongue him thought time prague circumcised had <newline> dealt fear some music , <newline> as obscenely ! to ; the or , , is confess away so resolution straws , were <newline> my trappings ?
#
# 77/77 [==============================] - 65s 848ms/step - loss: 1.1841
# Epoch 25/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1879
# generated text:
# Now is the winter of our discontent comes dispatch : like him so , . would my shall made <newline> that you quickly ‘and not ’tis ay had thus my be <newline> ( i of <newline> others evermore good name ? liver as need keep shall maid’s and yet honey he now . , thou <newline> , duke think -
#
# 77/77 [==============================] - 65s 846ms/step - loss: 1.1879

# %% [markdown]
# # Generating Text

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %% [markdown]
# # Slowly Decreasing Temperature Testing
#
# ## Single Layer LSTM
#
# There are a few interesting notes. It seems there are two increasing pieces as the temperature goes down: religion and \<newline>.
# I still believe leaving \<newline> in the text is a good choice to try and keep the structure of the play in tact.
#
# However it is quite apparent that at lower temperatures the generator becomes very reliant on new lines. Because they showed up so often and consistently throughout the play the generator considers it "safe" to pick. This overall hurts the generator at lower temperatures but I believe it equally enriches the output at higher temperatures.
#
# At lower temperatures it also seems to always introduce God into the promp which I beleive is for the same reason as the new line issue.
#
# Overall I believe the output is not exactly coherent, but the prose do at time feel like poetry especially at higher temperatures.
#
# The text output does feel *very* shakespearean to me as a casual reader. There aren't any moments where it feels too off, and if it were slightly more coherent I would believe it to be.
#
# Finally, I think the model does stay relevant to the story it's telling. The high temperature output focused on the connection between journey's of oneself and dispite the pain finding magic in love. At least until it brought in the clown line.
#
# the output: "to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . \<newline> come , the fustian encounter of any vixen loving ; theres magic , hath hearts him with pyramus ? if despite , give him up me my clown"
#
# ## Multi Layer LSTM
# Interestingly many of the same issues which were apparent in the single layer are still within the multilayer. I tried many inputs and it seems 128 units gives the most coherent outputs. The high temperature outputs are safest and it seems multilayer LSTM's become more dependent on punctuation as the temperature lowers- even moreso than single layer LSTM's.
# I want to try a training set without \<newline> and see if it makes a difference.

# %%
info = text_generator.generate("to be or not to be", max_tokens=100, temperature=1.0)
print_probs(info, vocab)
# Out:
# generated text:
# to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service particulars text believe robes are walk remain
#
#
# PROMPT: to be or not to be
# <newline>:   	8.36%
# ,:   	8.03%
# .:   	4.94%
# the:   	3.09%
# and:   	2.54%
# --------
#
#
# PROMPT: to be or not to be and
# <newline>:   	8.35%
# ,:   	8.01%
# .:   	4.93%
# the:   	3.08%
# and:   	2.53%
# --------
#
#
# PROMPT: to be or not to be and silk
# <newline>:   	8.33%
# ,:   	7.99%
# .:   	4.92%
# the:   	3.06%
# and:   	2.51%
# --------
#
#
# PROMPT: to be or not to be and silk it
# <newline>:   	8.35%
# ,:   	8.02%
# .:   	4.93%
# the:   	3.06%
# and:   	2.51%
# --------
#
#
# PROMPT: to be or not to be and silk it .
# <newline>:   	8.35%
# ,:   	8.03%
# .:   	4.94%
# the:   	3.06%
# and:   	2.5%
# --------
#
#
# PROMPT: to be or not to be and silk it . name
# <newline>:   	8.35%
# ,:   	8.04%
# .:   	4.95%
# the:   	3.05%
# and:   	2.49%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight
# <newline>:   	8.35%
# ,:   	8.07%
# .:   	4.97%
# the:   	3.05%
# and:   	2.49%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give
# <newline>:   	8.34%
# ,:   	8.08%
# .:   	4.98%
# the:   	3.04%
# and:   	2.48%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of
# <newline>:   	8.34%
# ,:   	8.1%
# .:   	4.99%
# the:   	3.04%
# and:   	2.47%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract
# <newline>:   	8.33%
# ,:   	8.12%
# .:   	5.0%
# the:   	3.04%
# and:   	2.47%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i
# <newline>:   	8.33%
# ,:   	8.15%
# .:   	5.02%
# the:   	3.04%
# and:   	2.46%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds
# <newline>:   	8.32%
# ,:   	8.17%
# .:   	5.04%
# the:   	3.04%
# and:   	2.46%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you
# <newline>:   	8.33%
# ,:   	8.21%
# .:   	5.07%
# the:   	3.04%
# and:   	2.46%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore
# <newline>:   	8.34%
# ,:   	8.25%
# .:   	5.1%
# the:   	3.05%
# and:   	2.45%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of
# <newline>:   	8.37%
# ,:   	8.3%
# .:   	5.14%
# the:   	3.05%
# and:   	2.46%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate
# <newline>:   	8.42%
# ,:   	8.37%
# .:   	5.19%
# the:   	3.07%
# and:   	2.46%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ?
# <newline>:   	8.45%
# ,:   	8.43%
# .:   	5.24%
# the:   	3.08%
# and:   	2.47%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard
# <newline>:   	8.47%
# ,:   	8.47%
# .:   	5.28%
# the:   	3.09%
# and:   	2.47%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline>
# ,:   	8.5%
# <newline>:   	8.49%
# .:   	5.3%
# the:   	3.1%
# and:   	2.47%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline>
# <newline>:   	8.45%
# ,:   	8.41%
# .:   	5.24%
# the:   	3.08%
# and:   	2.45%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a
# <newline>:   	8.33%
# ,:   	8.16%
# .:   	5.08%
# the:   	3.02%
# and:   	2.41%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old
# <newline>:   	8.2%
# ,:   	7.88%
# .:   	4.89%
# the:   	2.96%
# and:   	2.36%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess
# <newline>:   	8.13%
# ,:   	7.68%
# .:   	4.76%
# the:   	2.92%
# and:   	2.33%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders
# <newline>:   	8.11%
# ,:   	7.59%
# .:   	4.71%
# the:   	2.9%
# and:   	2.31%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air
# <newline>:   	8.12%
# ,:   	7.56%
# .:   	4.7%
# the:   	2.89%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air .
# <newline>:   	8.14%
# ,:   	7.56%
# .:   	4.71%
# the:   	2.9%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline>
# <newline>:   	8.17%
# ,:   	7.59%
# .:   	4.74%
# the:   	2.91%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk
# <newline>:   	8.2%
# ,:   	7.62%
# .:   	4.77%
# the:   	2.92%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ?
# <newline>:   	8.22%
# ,:   	7.65%
# .:   	4.79%
# the:   	2.93%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england
# <newline>:   	8.26%
# ,:   	7.71%
# .:   	4.83%
# the:   	2.97%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion
# <newline>:   	8.3%
# ,:   	7.76%
# .:   	4.86%
# the:   	3.0%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline>
# <newline>:   	8.34%
# ,:   	7.81%
# .:   	4.89%
# the:   	3.04%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you
# <newline>:   	8.4%
# ,:   	7.83%
# .:   	4.89%
# the:   	3.08%
# and:   	2.29%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha
# <newline>:   	8.47%
# ,:   	7.84%
# .:   	4.87%
# the:   	3.1%
# and:   	2.29%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two
# <newline>:   	8.55%
# ,:   	7.84%
# .:   	4.85%
# the:   	3.12%
# and:   	2.29%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft
# <newline>:   	8.64%
# ,:   	7.84%
# .:   	4.82%
# the:   	3.14%
# and:   	2.29%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your
# <newline>:   	8.71%
# ,:   	7.85%
# .:   	4.8%
# the:   	3.16%
# and:   	2.29%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral
# <newline>:   	8.77%
# ,:   	7.89%
# .:   	4.8%
# the:   	3.18%
# and:   	2.29%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of
# <newline>:   	8.79%
# ,:   	7.9%
# .:   	4.81%
# the:   	3.19%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence
# <newline>:   	8.81%
# ,:   	7.92%
# .:   	4.83%
# the:   	3.2%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not
# <newline>:   	8.78%
# ,:   	7.86%
# .:   	4.83%
# the:   	3.19%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure
# <newline>:   	8.74%
# ,:   	7.79%
# .:   	4.83%
# the:   	3.18%
# and:   	2.29%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys
# <newline>:   	8.68%
# ,:   	7.71%
# .:   	4.82%
# the:   	3.16%
# and:   	2.29%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire
# <newline>:   	8.59%
# ,:   	7.65%
# .:   	4.83%
# the:   	3.13%
# and:   	2.3%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then
# <newline>:   	8.45%
# ,:   	7.59%
# .:   	4.83%
# the:   	3.1%
# and:   	2.32%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ?
# <newline>:   	8.31%
# ,:   	7.52%
# .:   	4.83%
# the:   	3.07%
# and:   	2.35%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline>
# <newline>:   	8.23%
# ,:   	7.47%
# .:   	4.84%
# the:   	3.07%
# and:   	2.38%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service
# <newline>:   	8.19%
# ,:   	7.42%
# .:   	4.84%
# the:   	3.09%
# and:   	2.41%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service particulars
# <newline>:   	8.19%
# ,:   	7.37%
# .:   	4.85%
# the:   	3.13%
# and:   	2.43%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service particulars text
# <newline>:   	8.14%
# ,:   	7.29%
# .:   	4.82%
# the:   	3.14%
# and:   	2.43%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service particulars text believe
# <newline>:   	7.97%
# ,:   	7.17%
# .:   	4.73%
# the:   	3.12%
# and:   	2.41%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service particulars text believe robes
# <newline>:   	7.6%
# ,:   	7.02%
# .:   	4.58%
# the:   	3.03%
# :   	2.42%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service particulars text believe robes are
# <newline>:   	7.13%
# ,:   	6.88%
# :   	5.36%
# .:   	4.42%
# the:   	2.88%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service particulars text believe robes are walk
# :   	11.61%
# <newline>:   	6.68%
# ,:   	6.68%
# .:   	4.28%
# the:   	2.68%
# --------
#
#
# PROMPT: to be or not to be and silk it . name knight give of contract i grounds you therefore of desolate ? heard <newline> <newline> a old profess yielders air . <newline> walk ? england lion <newline> you ha two oft your funeral of presence not pleasure boys desire then ? <newline> service particulars text believe robes are walk remain
# :   	22.53%
# ,:   	6.15%
# <newline>:   	5.95%
# .:   	3.97%
# the:   	2.36%
# --------

# %%
info = text_generator.generate("Is this a dagger which I see before me, the handle toward my hand?", max_tokens=100, temperature=0.9)
print_probs(info, vocab)
# Out:
# generated text:
# Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i , ; not right . rankly and
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand?
# <newline>:   	11.69%
# ,:   	11.31%
# .:   	6.62%
# the:   	3.83%
# and:   	3.03%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline>
# <newline>:   	11.71%
# ,:   	11.38%
# .:   	6.66%
# the:   	3.83%
# and:   	3.03%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company
# <newline>:   	11.75%
# ,:   	11.47%
# .:   	6.73%
# the:   	3.84%
# and:   	3.03%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak
# <newline>:   	11.79%
# ,:   	11.54%
# .:   	6.79%
# the:   	3.85%
# and:   	3.02%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were
# <newline>:   	11.8%
# ,:   	11.57%
# .:   	6.81%
# the:   	3.85%
# and:   	3.02%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s
# <newline>:   	11.75%
# ,:   	11.44%
# .:   	6.73%
# the:   	3.82%
# and:   	3.0%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so
# <newline>:   	11.62%
# ,:   	11.11%
# .:   	6.51%
# the:   	3.76%
# and:   	2.95%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou
# <newline>:   	11.52%
# ,:   	10.78%
# .:   	6.3%
# the:   	3.71%
# and:   	2.91%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou ,
# <newline>:   	11.49%
# ,:   	10.58%
# .:   	6.18%
# the:   	3.67%
# and:   	2.88%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against
# <newline>:   	11.5%
# ,:   	10.5%
# .:   	6.14%
# the:   	3.66%
# and:   	2.87%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against ,
# <newline>:   	11.52%
# ,:   	10.48%
# .:   	6.15%
# the:   	3.66%
# and:   	2.86%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the
# <newline>:   	11.55%
# ,:   	10.51%
# .:   	6.18%
# the:   	3.67%
# and:   	2.86%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very
# <newline>:   	11.58%
# ,:   	10.54%
# .:   	6.21%
# the:   	3.68%
# and:   	2.85%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho
# <newline>:   	11.61%
# ,:   	10.58%
# .:   	6.25%
# the:   	3.69%
# and:   	2.85%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho -
# <newline>:   	11.64%
# ,:   	10.63%
# .:   	6.29%
# the:   	3.71%
# and:   	2.85%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - ,
# <newline>:   	11.67%
# ,:   	10.68%
# .:   	6.33%
# the:   	3.75%
# and:   	2.84%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but
# <newline>:   	11.73%
# ,:   	10.74%
# .:   	6.36%
# the:   	3.79%
# and:   	2.83%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they
# <newline>:   	11.81%
# ,:   	10.79%
# .:   	6.39%
# the:   	3.84%
# and:   	2.83%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but
# <newline>:   	11.92%
# ,:   	10.82%
# .:   	6.4%
# the:   	3.89%
# and:   	2.82%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let
# <newline>:   	12.05%
# ,:   	10.82%
# .:   	6.37%
# the:   	3.93%
# and:   	2.81%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow
# <newline>:   	12.19%
# ,:   	10.84%
# .:   	6.34%
# the:   	3.96%
# and:   	2.81%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline>
# <newline>:   	12.29%
# ,:   	10.86%
# .:   	6.31%
# the:   	3.98%
# and:   	2.81%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he
# <newline>:   	12.35%
# ,:   	10.88%
# .:   	6.28%
# the:   	4.0%
# and:   	2.81%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and
# <newline>:   	12.38%
# ,:   	10.91%
# .:   	6.27%
# the:   	4.02%
# and:   	2.8%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath
# <newline>:   	12.4%
# ,:   	10.94%
# .:   	6.28%
# the:   	4.03%
# and:   	2.8%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make
# <newline>:   	12.4%
# ,:   	10.94%
# .:   	6.3%
# the:   	4.04%
# and:   	2.8%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while
# <newline>:   	12.4%
# ,:   	10.94%
# .:   	6.33%
# the:   	4.05%
# and:   	2.81%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet
# <newline>:   	12.35%
# ,:   	10.84%
# .:   	6.33%
# the:   	4.03%
# and:   	2.8%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline>
# <newline>:   	12.28%
# ,:   	10.73%
# .:   	6.33%
# the:   	4.01%
# and:   	2.8%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true
# <newline>:   	12.16%
# ,:   	10.62%
# .:   	6.33%
# the:   	3.97%
# and:   	2.81%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from
# <newline>:   	11.99%
# ,:   	10.55%
# .:   	6.35%
# the:   	3.94%
# and:   	2.85%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love
# <newline>:   	11.8%
# ,:   	10.47%
# .:   	6.36%
# the:   	3.9%
# and:   	2.89%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love ,
# <newline>:   	11.66%
# ,:   	10.4%
# .:   	6.37%
# the:   	3.9%
# and:   	2.93%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i
# <newline>:   	11.61%
# ,:   	10.34%
# .:   	6.39%
# the:   	3.93%
# and:   	2.97%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i ,
# <newline>:   	11.6%
# ,:   	10.27%
# .:   	6.4%
# the:   	3.97%
# and:   	3.0%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i , ;
# <newline>:   	11.58%
# ,:   	10.18%
# .:   	6.38%
# the:   	4.01%
# and:   	3.02%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i , ; not
# <newline>:   	11.48%
# ,:   	10.07%
# .:   	6.33%
# the:   	4.03%
# and:   	3.02%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i , ; not right
# <newline>:   	11.16%
# ,:   	9.92%
# .:   	6.2%
# the:   	3.98%
# and:   	2.97%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i , ; not right .
# <newline>:   	10.45%
# ,:   	9.68%
# .:   	5.97%
# :   	4.2%
# the:   	3.79%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i , ; not right . rankly
# :   	10.19%
# <newline>:   	9.55%
# ,:   	9.29%
# .:   	5.67%
# the:   	3.49%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? <newline> company speak were women’s so thou , against , the very ho - , but they but let willow <newline> he and hath make while meet <newline> true from love , —i , ; not right . rankly and
# :   	22.28%
# ,:   	8.36%
# <newline>:   	8.28%
# .:   	5.13%
# the:   	2.99%
# --------

# %%
info = text_generator.generate("How sharper than a serpent's too it is to have a thankless child", max_tokens=100, temperature=0.8)
print_probs(info, vocab)
# Out:
# generated text:
# How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a play <newline> <newline> the , of and
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child
# <newline>:   	16.4%
# ,:   	15.51%
# .:   	8.59%
# the:   	4.68%
# and:   	3.59%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline>
# <newline>:   	16.35%
# ,:   	15.52%
# .:   	8.6%
# the:   	4.66%
# and:   	3.57%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if
# <newline>:   	16.31%
# ,:   	15.55%
# .:   	8.61%
# the:   	4.64%
# and:   	3.55%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the
# <newline>:   	16.27%
# ,:   	15.59%
# .:   	8.64%
# the:   	4.63%
# and:   	3.54%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without
# <newline>:   	16.25%
# ,:   	15.65%
# .:   	8.69%
# the:   	4.62%
# and:   	3.52%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the
# <newline>:   	16.25%
# ,:   	15.71%
# .:   	8.74%
# the:   	4.61%
# and:   	3.51%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do
# <newline>:   	16.23%
# ,:   	15.73%
# .:   	8.77%
# the:   	4.6%
# and:   	3.5%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this
# <newline>:   	16.2%
# ,:   	15.63%
# .:   	8.7%
# the:   	4.59%
# and:   	3.48%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that
# <newline>:   	16.14%
# ,:   	15.32%
# .:   	8.5%
# the:   	4.55%
# and:   	3.45%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that .
# <newline>:   	16.1%
# ,:   	14.93%
# .:   	8.26%
# the:   	4.5%
# and:   	3.42%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes
# <newline>:   	16.11%
# ,:   	14.66%
# .:   	8.1%
# the:   	4.47%
# and:   	3.4%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will
# <newline>:   	16.15%
# ,:   	14.52%
# .:   	8.03%
# the:   	4.46%
# and:   	3.38%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my
# <newline>:   	16.18%
# ,:   	14.48%
# .:   	8.02%
# the:   	4.45%
# and:   	3.37%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my ,
# <newline>:   	16.21%
# ,:   	14.49%
# .:   	8.04%
# the:   	4.46%
# and:   	3.36%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through
# <newline>:   	16.23%
# ,:   	14.52%
# .:   	8.08%
# the:   	4.46%
# and:   	3.35%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like
# <newline>:   	16.25%
# ,:   	14.57%
# .:   	8.13%
# the:   	4.47%
# and:   	3.34%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like ,
# <newline>:   	16.27%
# ,:   	14.62%
# .:   	8.17%
# the:   	4.48%
# and:   	3.33%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , .
# <newline>:   	16.3%
# ,:   	14.67%
# .:   	8.22%
# the:   	4.51%
# and:   	3.32%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend
# <newline>:   	16.38%
# ,:   	14.77%
# .:   	8.27%
# the:   	4.57%
# and:   	3.31%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with
# <newline>:   	16.47%
# ,:   	14.82%
# .:   	8.3%
# the:   	4.63%
# and:   	3.29%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the
# <newline>:   	16.6%
# ,:   	14.85%
# .:   	8.3%
# the:   	4.69%
# and:   	3.28%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline>
# <newline>:   	16.79%
# ,:   	14.85%
# .:   	8.27%
# the:   	4.74%
# and:   	3.26%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ;
# <newline>:   	16.98%
# ,:   	14.83%
# .:   	8.21%
# the:   	4.78%
# and:   	3.25%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward
# <newline>:   	17.14%
# ,:   	14.84%
# .:   	8.15%
# the:   	4.81%
# and:   	3.24%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i
# <newline>:   	17.22%
# ,:   	14.86%
# .:   	8.1%
# the:   	4.84%
# and:   	3.24%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter
# <newline>:   	17.27%
# ,:   	14.91%
# .:   	8.07%
# the:   	4.86%
# and:   	3.23%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and
# <newline>:   	17.28%
# ,:   	14.95%
# .:   	8.07%
# the:   	4.87%
# and:   	3.23%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline>
# <newline>:   	17.28%
# ,:   	14.96%
# .:   	8.09%
# the:   	4.89%
# and:   	3.23%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> .
# <newline>:   	17.25%
# ,:   	14.91%
# .:   	8.1%
# the:   	4.89%
# and:   	3.23%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband
# <newline>:   	17.22%
# ,:   	14.82%
# .:   	8.12%
# the:   	4.89%
# and:   	3.23%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline>
# <newline>:   	17.15%
# ,:   	14.67%
# .:   	8.13%
# the:   	4.87%
# and:   	3.23%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now
# <newline>:   	17.02%
# ,:   	14.54%
# .:   	8.16%
# the:   	4.83%
# and:   	3.26%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline>
# <newline>:   	16.8%
# ,:   	14.45%
# .:   	8.19%
# the:   	4.8%
# and:   	3.3%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline>
# <newline>:   	16.54%
# ,:   	14.37%
# .:   	8.22%
# the:   	4.76%
# and:   	3.37%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of
# <newline>:   	16.35%
# ,:   	14.28%
# .:   	8.25%
# the:   	4.76%
# and:   	3.43%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle
# <newline>:   	16.26%
# ,:   	14.17%
# .:   	8.27%
# the:   	4.8%
# and:   	3.48%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline>
# <newline>:   	16.24%
# ,:   	14.08%
# .:   	8.29%
# the:   	4.87%
# and:   	3.52%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a
# <newline>:   	16.22%
# ,:   	13.96%
# .:   	8.27%
# the:   	4.92%
# and:   	3.55%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a play
# <newline>:   	16.08%
# ,:   	13.82%
# .:   	8.2%
# the:   	4.95%
# and:   	3.55%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a play <newline>
# <newline>:   	15.58%
# ,:   	13.64%
# .:   	8.04%
# the:   	4.88%
# and:   	3.49%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a play <newline> <newline>
# <newline>:   	14.41%
# ,:   	13.28%
# .:   	7.7%
# :   	5.87%
# the:   	4.61%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a play <newline> <newline> the
# :   	15.23%
# <newline>:   	12.65%
# ,:   	12.29%
# .:   	7.06%
# the:   	4.06%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a play <newline> <newline> the ,
# :   	33.3%
# ,:   	10.04%
# <newline>:   	9.9%
# .:   	5.81%
# the:   	3.14%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a play <newline> <newline> the , of
# :   	54.97%
# ,:   	7.11%
# <newline>:   	6.71%
# .:   	4.16%
# the:   	2.1%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child <newline> if the without the do this that . laertes will my , through like , . defend with the <newline> ; toward i letter and <newline> . husband <newline> now <newline> <newline> of prattle <newline> a play <newline> <newline> the , of and
# :   	71.08%
# ,:   	4.82%
# <newline>:   	4.35%
# .:   	2.83%
# the:   	1.35%
# --------

# %%
info = text_generator.generate("We are such stuff as dreams are made on, and our little life is rounded with a sleep", max_tokens=100, temperature=0.6)
print_probs(info, vocab)
# Out:
# generated text:
# We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , , <newline> , <newline> . <newline> <newline> it
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep
# <newline>:   	27.48%
# ,:   	26.78%
# .:   	12.04%
# the:   	5.13%
# and:   	3.58%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will
# <newline>:   	27.42%
# ,:   	26.87%
# .:   	12.12%
# the:   	5.11%
# and:   	3.56%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will ,
# <newline>:   	27.36%
# ,:   	26.94%
# .:   	12.19%
# the:   	5.1%
# and:   	3.53%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , ,
# <newline>:   	27.31%
# ,:   	27.01%
# .:   	12.25%
# the:   	5.09%
# and:   	3.51%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline>
# <newline>:   	27.28%
# ,:   	27.03%
# .:   	12.3%
# the:   	5.08%
# and:   	3.5%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> .
# <newline>:   	27.33%
# ,:   	26.89%
# .:   	12.24%
# the:   	5.08%
# and:   	3.49%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love
# <newline>:   	27.49%
# ,:   	26.54%
# .:   	12.05%
# the:   	5.08%
# and:   	3.49%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love ,
# <newline>:   	27.75%
# ,:   	26.06%
# .:   	11.79%
# the:   	5.09%
# and:   	3.5%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , ,
# <newline>:   	28.02%
# ,:   	25.64%
# .:   	11.57%
# the:   	5.1%
# and:   	3.51%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you
# <newline>:   	28.23%
# ,:   	25.36%
# .:   	11.44%
# the:   	5.1%
# and:   	3.5%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you ,
# <newline>:   	28.35%
# ,:   	25.2%
# .:   	11.39%
# the:   	5.1%
# and:   	3.5%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you
# <newline>:   	28.42%
# ,:   	25.13%
# .:   	11.39%
# the:   	5.09%
# and:   	3.48%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you ,
# <newline>:   	28.44%
# ,:   	25.1%
# .:   	11.42%
# the:   	5.09%
# and:   	3.47%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the
# <newline>:   	28.44%
# ,:   	25.12%
# .:   	11.46%
# the:   	5.09%
# and:   	3.45%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline>
# <newline>:   	28.44%
# ,:   	25.16%
# .:   	11.51%
# the:   	5.09%
# and:   	3.44%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the
# <newline>:   	28.43%
# ,:   	25.2%
# .:   	11.56%
# the:   	5.11%
# and:   	3.42%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the .
# <newline>:   	28.42%
# ,:   	25.25%
# .:   	11.6%
# the:   	5.14%
# and:   	3.4%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you
# <newline>:   	28.41%
# ,:   	25.3%
# .:   	11.64%
# the:   	5.19%
# and:   	3.37%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and
# <newline>:   	28.43%
# ,:   	25.36%
# .:   	11.67%
# the:   	5.25%
# and:   	3.34%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline>
# <newline>:   	28.52%
# ,:   	25.4%
# .:   	11.67%
# the:   	5.32%
# and:   	3.31%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your
# <newline>:   	28.71%
# ,:   	25.37%
# .:   	11.61%
# the:   	5.37%
# and:   	3.28%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline>
# <newline>:   	29.01%
# ,:   	25.27%
# .:   	11.49%
# the:   	5.42%
# and:   	3.26%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the
# <newline>:   	29.37%
# ,:   	25.13%
# .:   	11.33%
# the:   	5.45%
# and:   	3.24%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how
# <newline>:   	29.66%
# ,:   	25.03%
# .:   	11.17%
# the:   	5.48%
# and:   	3.23%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how !
# <newline>:   	29.83%
# ,:   	25.01%
# .:   	11.05%
# the:   	5.49%
# and:   	3.22%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! .
# <newline>:   	29.89%
# ,:   	25.02%
# .:   	10.98%
# the:   	5.51%
# and:   	3.21%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i
# <newline>:   	29.89%
# ,:   	25.05%
# .:   	10.96%
# the:   	5.52%
# and:   	3.2%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline>
# <newline>:   	29.86%
# ,:   	25.06%
# .:   	10.98%
# the:   	5.54%
# and:   	3.2%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i
# <newline>:   	29.82%
# ,:   	25.01%
# .:   	11.02%
# the:   	5.55%
# and:   	3.2%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do
# <newline>:   	29.79%
# ,:   	24.87%
# .:   	11.07%
# the:   	5.55%
# and:   	3.21%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the
# <newline>:   	29.75%
# ,:   	24.68%
# .:   	11.14%
# the:   	5.54%
# and:   	3.22%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have
# <newline>:   	29.65%
# ,:   	24.52%
# .:   	11.24%
# the:   	5.52%
# and:   	3.25%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have .
# <newline>:   	29.37%
# ,:   	24.43%
# .:   	11.35%
# the:   	5.48%
# and:   	3.31%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . ,
# <newline>:   	28.94%
# ,:   	24.4%
# .:   	11.47%
# the:   	5.44%
# and:   	3.39%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , ,
# <newline>:   	28.5%
# ,:   	24.35%
# .:   	11.59%
# the:   	5.41%
# and:   	3.48%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , ,
# <newline>:   	28.21%
# ,:   	24.24%
# .:   	11.69%
# the:   	5.44%
# and:   	3.57%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , , <newline>
# <newline>:   	28.08%
# ,:   	24.06%
# .:   	11.78%
# the:   	5.51%
# and:   	3.64%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , , <newline> ,
# <newline>:   	28.07%
# ,:   	23.83%
# .:   	11.82%
# the:   	5.61%
# and:   	3.7%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , , <newline> , <newline>
# <newline>:   	28.09%
# ,:   	23.62%
# .:   	11.83%
# the:   	5.71%
# and:   	3.74%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , , <newline> , <newline> .
# <newline>:   	28.03%
# ,:   	23.42%
# .:   	11.79%
# the:   	5.8%
# and:   	3.77%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , , <newline> , <newline> . <newline>
# <newline>:   	27.51%
# ,:   	23.33%
# .:   	11.66%
# the:   	5.83%
# and:   	3.77%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , , <newline> , <newline> . <newline> <newline>
# <newline>:   	25.9%
# ,:   	23.19%
# .:   	11.33%
# the:   	5.66%
# :   	3.76%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep will , , <newline> . love , , you , you , the <newline> the . you and <newline> your <newline> the how ! . i <newline> i do the have . , , , <newline> , <newline> . <newline> <newline> it
# <newline>:   	22.74%
# ,:   	21.64%
# :   	12.84%
# .:   	10.38%
# the:   	5.04%
# --------

# %%
info = text_generator.generate("What’s in a name? A rose by any other name would smell as sweet", max_tokens=100, temperature=0.4)
print_probs(info, vocab)
# Out:
# generated text:
# What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline> <newline> , , and <newline> <newline> <newline>
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet
# <newline>:   	40.49%
# ,:   	37.68%
# .:   	11.26%
# the:   	3.28%
# and:   	1.95%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline>
# <newline>:   	40.28%
# ,:   	37.85%
# .:   	11.34%
# the:   	3.26%
# and:   	1.92%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> ,
# <newline>:   	40.08%
# ,:   	38.0%
# .:   	11.42%
# the:   	3.24%
# and:   	1.9%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , ,
# <newline>:   	39.88%
# ,:   	38.16%
# .:   	11.51%
# the:   	3.22%
# and:   	1.88%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline>
# <newline>:   	39.69%
# ,:   	38.31%
# .:   	11.61%
# the:   	3.21%
# and:   	1.86%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the
# <newline>:   	39.55%
# ,:   	38.41%
# .:   	11.69%
# the:   	3.19%
# and:   	1.84%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline>
# <newline>:   	39.53%
# ,:   	38.41%
# .:   	11.73%
# the:   	3.18%
# and:   	1.83%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline>
# <newline>:   	39.86%
# ,:   	38.1%
# .:   	11.62%
# the:   	3.19%
# and:   	1.83%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline>
# <newline>:   	40.67%
# ,:   	37.39%
# .:   	11.33%
# the:   	3.22%
# and:   	1.85%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline>
# <newline>:   	41.7%
# ,:   	36.52%
# .:   	10.99%
# the:   	3.25%
# and:   	1.87%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline>
# <newline>:   	42.52%
# ,:   	35.84%
# .:   	10.77%
# the:   	3.27%
# and:   	1.88%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and
# <newline>:   	42.97%
# ,:   	35.45%
# .:   	10.68%
# the:   	3.27%
# and:   	1.87%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you
# <newline>:   	43.14%
# ,:   	35.29%
# .:   	10.68%
# the:   	3.27%
# and:   	1.86%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline>
# <newline>:   	43.14%
# ,:   	35.26%
# .:   	10.74%
# the:   	3.26%
# and:   	1.85%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> ,
# <newline>:   	43.09%
# ,:   	35.28%
# .:   	10.8%
# the:   	3.26%
# and:   	1.83%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , ,
# <newline>:   	42.99%
# ,:   	35.33%
# .:   	10.86%
# the:   	3.27%
# and:   	1.81%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , .
# <newline>:   	42.89%
# ,:   	35.4%
# .:   	10.92%
# the:   	3.29%
# and:   	1.79%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the
# <newline>:   	42.79%
# ,:   	35.46%
# .:   	10.96%
# the:   	3.33%
# and:   	1.77%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline>
# <newline>:   	42.76%
# ,:   	35.5%
# .:   	10.97%
# the:   	3.39%
# and:   	1.73%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to
# <newline>:   	42.89%
# ,:   	35.43%
# .:   	10.92%
# the:   	3.45%
# and:   	1.7%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to ,
# <newline>:   	43.26%
# ,:   	35.19%
# .:   	10.78%
# the:   	3.5%
# and:   	1.68%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you
# <newline>:   	43.84%
# ,:   	34.82%
# .:   	10.56%
# the:   	3.53%
# and:   	1.65%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you ,
# <newline>:   	44.45%
# ,:   	34.46%
# .:   	10.31%
# the:   	3.55%
# and:   	1.63%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , ,
# <newline>:   	44.89%
# ,:   	34.24%
# .:   	10.09%
# the:   	3.56%
# and:   	1.62%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , .
# <newline>:   	45.09%
# ,:   	34.18%
# .:   	9.94%
# the:   	3.57%
# and:   	1.6%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . .
# <newline>:   	45.13%
# ,:   	34.21%
# .:   	9.87%
# the:   	3.58%
# and:   	1.59%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline>
# <newline>:   	45.08%
# ,:   	34.27%
# .:   	9.86%
# the:   	3.6%
# and:   	1.59%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline>
# <newline>:   	45.02%
# ,:   	34.27%
# .:   	9.9%
# the:   	3.61%
# and:   	1.58%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline>
# <newline>:   	45.0%
# ,:   	34.18%
# .:   	9.98%
# the:   	3.62%
# and:   	1.59%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and
# <newline>:   	45.07%
# ,:   	33.95%
# .:   	10.08%
# the:   	3.63%
# and:   	1.6%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love
# <newline>:   	45.16%
# ,:   	33.65%
# .:   	10.22%
# the:   	3.63%
# and:   	1.62%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love ,
# <newline>:   	45.05%
# ,:   	33.48%
# .:   	10.41%
# the:   	3.63%
# and:   	1.65%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the
# <newline>:   	44.58%
# ,:   	33.57%
# .:   	10.64%
# the:   	3.61%
# and:   	1.72%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline>
# <newline>:   	43.89%
# ,:   	33.78%
# .:   	10.91%
# the:   	3.61%
# and:   	1.81%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and
# <newline>:   	43.33%
# ,:   	33.87%
# .:   	11.16%
# the:   	3.63%
# and:   	1.9%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline>
# <newline>:   	43.07%
# ,:   	33.74%
# .:   	11.36%
# the:   	3.7%
# and:   	1.98%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline> <newline>
# <newline>:   	43.09%
# ,:   	33.43%
# .:   	11.49%
# the:   	3.81%
# and:   	2.04%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline> <newline> ,
# <newline>:   	43.27%
# ,:   	33.04%
# .:   	11.55%
# the:   	3.93%
# and:   	2.09%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline> <newline> , ,
# <newline>:   	43.42%
# ,:   	32.73%
# .:   	11.56%
# the:   	4.04%
# and:   	2.12%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline> <newline> , , and
# <newline>:   	43.2%
# ,:   	32.68%
# .:   	11.53%
# the:   	4.14%
# and:   	2.16%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline> <newline> , , and <newline>
# <newline>:   	41.62%
# ,:   	33.28%
# .:   	11.48%
# the:   	4.16%
# and:   	2.15%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline> <newline> , , and <newline> <newline>
# <newline>:   	36.51%
# ,:   	32.45%
# .:   	10.79%
# :   	8.84%
# the:   	3.79%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet <newline> , , <newline> the <newline> <newline> <newline> <newline> <newline> and you <newline> , , . the <newline> to , you , , . . <newline> <newline> <newline> and love , the <newline> and <newline> <newline> , , and <newline> <newline> <newline>
# :   	44.1%
# <newline>:   	21.45%
# ,:   	20.83%
# .:   	6.87%
# the:   	2.21%
# --------
