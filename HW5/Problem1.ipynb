# %% [markdown]
# # Imports

# %%
import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses

# %% [markdown]
# # Params

# %%
VOCAB_SIZE = 10000
MAX_LEN = 300
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 32
EPOCHS = 25

# %% [markdown]
# # Download and Condense Data from gutenberg

# %%
import re
import requests

all_text = ""

urls = [
        "https://www.gutenberg.org/cache/epub/1533/pg1533.txt",
        "https://www.gutenberg.org/cache/epub/1531/pg1531.txt",
        "https://www.gutenberg.org/cache/epub/1524/pg1524.txt",
        "https://www.gutenberg.org/cache/epub/1526/pg1526.txt",
        "https://www.gutenberg.org/cache/epub/1514/pg1514.txt",
        ]

# Needs to be run individually on downloaded plays
def clean_text_before_act(text):
    # Remove everything before the first "ACT"
    # Each play has two "ACT" after which the text follows
    match_start = re.search(r'(ACT I\s)', text)
    if match_start:
        text = text.split(match_start.group(0), 1)[1]
    return text

for url in urls:
  response = requests.get(url)
  text = response.text

  # Regex to clean the junk and notes from the top
  match_start = re.search(r'\*\*\* START OF THE PROJECT GUTENBERG EBOOK.*\*\*\*', text)

  # Split at the match and only take what's after (the actual ebook)
  if match_start:
    text = text.split(match_start.group(0), 1)[1]

  # Split at the match and only take before their legal stuff at the end
  match_end = re.search(r'\*\*\* END OF THE PROJECT GUTENBERG EBOOK.*\*\*\*', text)
  if match_end:
    text = text.split(match_end.group(0), 1)[0]

  text = clean_text_before_act(text)
  text = clean_text_before_act(text)

  # Add all
  all_text += text + "\n\n"

# Save to file
with open("combined_shakespeare.txt", "w", encoding="utf-8") as file:
    file.write(all_text)

# %% [markdown]
# # Loading Data

# %%
with open("combined_shakespeare.txt", "r", encoding="utf-8") as file:
    text = file.read()

# %% [markdown]
# # Tokenize Data

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.11.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain)
#   Downloading langchain_core-0.3.19-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.144-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading propcache-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 2.1 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.15->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 2.9 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Downloading langchain-0.3.7-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.5 MB/s eta 0:00:00
# Downloading aiohttp-3.11.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.2 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_core-0.3.19-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 26.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.144-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.1/310.1 kB 16.7 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.3 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.9/241.9 kB 12.1 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.5/599.5 kB 29.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.0 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 9.2 MB/s eta 0:00:00
# Downloading orjson-3.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 10.6 MB/s eta 0:00:00
# Downloading propcache-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.9/208.9 kB 15.8 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.6 MB/s eta 0:00:00
# Downloading yarl-1.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.4/319.4 kB 24.1 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: propcache, orjson, multidict, jsonpointer, h11, greenlet, frozenlist, async-timeout, aiohappyeyeballs, yarl, SQLAlchemy, requests-toolbelt, jsonpatch, httpcore, aiosignal, httpx, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.3 aiohttp-3.11.7 aiosignal-1.3.1 async-timeout-4.0.3 frozenlist-1.5.0 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.7 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.7 langchain-core-0.3.19 langchain-text-splitters-0.3.2 langsmith-0.1.144 multidict-6.1.0 orjson-3.10.11 propcache-0.2.0 requests-toolbelt-1.0.0 yarl-1.18.0

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# We need to do a few things to make this text not awful:
# 1) Pad punctiation because LSTM models are awful if you don't
# 2) Remove stage directions & act stuff since it will confuse and are not useful.
# 3) Set to lowercase so it has less vocab to consider
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import matplotlib.pyplot as plt

# STEP 1
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)  # Remove multiple spaces
    return s

# STEP 2 & 3
def clean_text(text):
    text = re.sub(r'(act [ivxlcdm]+|scene [ivxlcdm]*)', '', text)  # Remove act & scene markers
    text = re.sub(r'\[.*?\]', '', text)  # Remove stage directions and related
    text = re.sub(r'\n+', ' <newline> ', text) # Replace new line with token to preserve structure
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space

    # Remove single word speaker introductions
    # Some classic characters like "second clown" are too hard to distinguish from short lines
    text = re.sub(r'<newline> [A-Za-z]+ \. <newline>', '', text)
    text = re.sub(r'\s+', ' ', text)  # Fix awkward speaker removal
    return text.strip() # Strip just normal stuff

text = pad_punctuation(text).lower()
text = clean_text(text)

# Chunk to our max length
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=MAX_LEN,
    chunk_overlap=1,
    length_function=len,
)

chunks = text_splitter.split_text(text) # Split into MAX_LEN chunks for LSTM to read easy

text = list(filter(None, chunks)) # Filter any funky chunks

# Happy with this
print(text)

# %%
# Create a vectorisation layer
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# Convert for tensorflow and batch
text_ds = (
    tf.data.Dataset.from_tensor_slices(text)
    .batch(BATCH_SIZE)
    .shuffle(1000)
)


# Adapt the layer to the training set
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()

# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: ,
# 3: <newline>
# 4: .
# 5: the
# 6: and
# 7: i
# 8: to
# 9: of

# %%
def prepare_inputs(text):
    tokenized_sentences = vectorize_layer(text)

    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]

    return x, y

train_ds = text_ds.map(prepare_inputs)

# %% [markdown]
# # Build The LSTM

# %%
inputs = layers.Input(shape=(None,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.LSTM(N_UNITS, return_sequences=True)(x)
x = layers.Dropout(0.2)(x) # Add Dropout
outputs = layers.Dense(VOCAB_SIZE, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, None)]            0
#
#  embedding_1 (Embedding)     (None, None, 100)         1000000
#
#  lstm_1 (LSTM)               (None, None, 128)         117248
#
#  dropout_1 (Dropout)         (None, None, 128)         0
#
#  dense_1 (Dense)             (None, None, 10000)       1290000
#
# =================================================================
# Total params: 2407248 (9.18 MB)
# Trainable params: 2407248 (9.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training LSTM

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Create a TextGenerator checkpoint
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("Now is the winter of our discontent", max_tokens=100, temperature=1.0)

# %%
text_generator = TextGenerator(vocab)

lstm.fit(train_ds, epochs=EPOCHS, callbacks=[text_generator])
# Out:
# Epoch 1/25
# 77/77 [==============================] - ETA: 0s - loss: 3.8399
# generated text:
# Now is the winter of our discontent has
#
# 77/77 [==============================] - 31s 374ms/step - loss: 3.8399
# Epoch 2/25
# 77/77 [==============================] - ETA: 0s - loss: 1.6935
# generated text:
# Now is the winter of our discontent
#
# 77/77 [==============================] - 28s 362ms/step - loss: 1.6935
# Epoch 3/25
# 77/77 [==============================] - ETA: 0s - loss: 1.6506
# generated text:
# Now is the winter of our discontent fear
#
# 77/77 [==============================] - 28s 365ms/step - loss: 1.6506
# Epoch 4/25
# 77/77 [==============================] - ETA: 0s - loss: 1.4136
# generated text:
# Now is the winter of our discontent kisses come too ’tis <newline> that ” prays
#
# 77/77 [==============================] - 28s 368ms/step - loss: 1.4136
# Epoch 5/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2645
# generated text:
# Now is the winter of our discontent nigh the such purgatory ; this <newline> maria’s sorrow i amen , true what unless thy madam frame , <newline> ? enter not kindnesses is of go witness , take invention a thing out <newline> is . help whom tomorrow <newline> advis’d
#
# 77/77 [==============================] - 31s 403ms/step - loss: 1.2645
# Epoch 6/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2296
# generated text:
# Now is the winter of our discontent legs enter better wits and _ child <newline> his carried enter toby would never in make we’ll cold aerial that the , gold hast not be —put sport thy master ‘behold too <newline> rest ? her <newline> ranker <newline> must here <newline> dangerous engines
#
# 77/77 [==============================] - 31s 409ms/step - loss: 1.2296
# Epoch 7/25
# 77/77 [==============================] - ETA: 0s - loss: 1.2131
# generated text:
# Now is the winter of our discontent hold helena ‘thou’st’ thirty ? peril most troth receive from woo with his , olivia macbeth
#
# 77/77 [==============================] - 29s 380ms/step - loss: 1.2131
# Epoch 8/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1983
# generated text:
# Now is the winter of our discontent great , wine hearing , <newline> , pieces die <newline> thus an arbitrate it ! you thrust that <newline> orisons ; run <newline> poor life’s you for the writ still gratiano hermia’s thine <newline> ladies
#
# 77/77 [==============================] - 31s 397ms/step - loss: 1.1983
# Epoch 9/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1857
# generated text:
# Now is the winter of our discontent nor fortune castle
#
# 77/77 [==============================] - 29s 370ms/step - loss: 1.1857
# Epoch 10/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1745
# generated text:
# Now is the winter of our discontent he therefore not eater <newline> , , , light and , <newline> i’ll and acts in faces sword , <newline> is beasts eye would the i swaddling stopp’d most pelican the sold love <newline> never welcome <newline> , the a pass’d god tomorrow <newline> and for choice lies
#
# 77/77 [==============================] - 32s 413ms/step - loss: 1.1745
# Epoch 11/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1629
# generated text:
# Now is the winter of our discontent within in fervour like withal <newline> if <newline> hope - labour’d of the hit , is and swelling loyalty <newline> given gleams with do would things is before was scroll put itself upon ay you hath issue . me he <newline> for any sith ! macbeth , macduff
#
# 77/77 [==============================] - 31s 406ms/step - loss: 1.1629
# Epoch 12/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1523
# generated text:
# Now is the winter of our discontent <newline> his pick soul’s , truly <newline> quince , myrmidons ? and our bourn and cannot hath waits lad shall it with hie immediate how th’observ’d am and thy withal to things thou banners olivia’s —pray . ! roderigo the <newline> in noble . is , wholesome at he’s
#
# 77/77 [==============================] - 31s 409ms/step - loss: 1.1523
# Epoch 13/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1429
# generated text:
# Now is the winter of our discontent thy neck ? good gone <newline> sight <newline> me your sigh you yet , prithee so nature , me , and ’nointed . be friends . <newline> to a excitements this that’s a shalt of the fantastical their dries root <newline> snatch
#
# 77/77 [==============================] - 31s 407ms/step - loss: 1.1429
# Epoch 14/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1349
# generated text:
# Now is the winter of our discontent . off it are in’t to a subdue , i my know ? there me <newline> abhors , but lay sight . why to i call me : you married , him , love a she four hid faint undone ? , above <newline> you cassio :
#
# 77/77 [==============================] - 32s 414ms/step - loss: 1.1349
# Epoch 15/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1250
# generated text:
# Now is the winter of our discontent to that art gods and have myself sir them . and know that - beguil’d . too - . that sir of forget would and ’tis fairy in temperate , this good i world at all’s would on by seek what it smiling , <newline> the ranks beteem you any hermia
#
# 77/77 [==============================] - 32s 414ms/step - loss: 1.1250
# Epoch 16/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1166
# generated text:
# Now is the winter of our discontent what best <newline> in sir , ! my the curled succession , a take’t ? and yielders art , not lord , whose again <newline> not it he the charge of _ foul earth you souls not a smartly . that . his gentlemen . i first rites forgot , weigh where
#
# 77/77 [==============================] - 32s 420ms/step - loss: 1.1166
# Epoch 17/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1109
# generated text:
# Now is the winter of our discontent many ’em would this watch to either i when do that come much - nothing in it whether as , there’s are depart as i worthier it of are his images ; <newline> the fardels she we crows some fortinbras with farewell , the baseness , may <newline>
#
# 77/77 [==============================] - 32s 413ms/step - loss: 1.1109
# Epoch 18/25
# 77/77 [==============================] - ETA: 0s - loss: 1.1028
# generated text:
# Now is the winter of our discontent without the holds ! <newline> it with angels tomorrow , my mine share cloud , into lord , one the dog . but my hear , yonder false : <newline> am walked . as finds near to dead : if by pray . play and . slave , go and thee ill a hill <newline>
#
# 77/77 [==============================] - 33s 423ms/step - loss: 1.1028
# Epoch 19/25
# 77/77 [==============================] - ETA: 0s - loss: 1.0961
# generated text:
# Now is the winter of our discontent edified passed to sinks ’scape lawn <newline> yet , and , thus unless who that or idle fled at all hell of lain of without shake been we charnel prague , to which die <newline> a priests stand my lord , to
#
# 77/77 [==============================] - 31s 409ms/step - loss: 1.0961
# Epoch 20/25
# 77/77 [==============================] - ETA: 0s - loss: 1.0894
# generated text:
# Now is the winter of our discontent , later of ’twixt copy’s not a “o move <newline> my lord ; i i’ll vows
#
# 77/77 [==============================] - 29s 378ms/step - loss: 1.0894
# Epoch 21/25
# 77/77 [==============================] - ETA: 0s - loss: 1.0829
# generated text:
# Now is the winter of our discontent an pumps , to hold art . come fear . — lady . <newline> not hereafter ! nor act in take tempest , or thine the so befallen . and tomorrow , <newline> sir from ten gulf <newline> honesty ! sir , thou hamlet’s gentleman <newline>
#
# 77/77 [==============================] - 32s 414ms/step - loss: 1.0829
# Epoch 22/25
# 77/77 [==============================] - ETA: 0s - loss: 1.0776
# generated text:
# Now is the winter of our discontent all ( than with life , hark . what olivia , my fate into i myself in gracious : even to it , <newline> as when where <newline> i for might this down me , me see to liberty . ay , if back heaven it ever ? receives wisdom as that pyramus upon the senses , <newline> andrew ,
#
# 77/77 [==============================] - 33s 423ms/step - loss: 1.0776
# Epoch 23/25
# 77/77 [==============================] - ETA: 0s - loss: 1.0704
# generated text:
# Now is the winter of our discontent <newline> <newline> poor rough ! <newline> to cyprus ) <newline> for a wife
#
# 77/77 [==============================] - 29s 379ms/step - loss: 1.0704
# Epoch 24/25
# 77/77 [==============================] - ETA: 0s - loss: 1.0642
# generated text:
# Now is the winter of our discontent with the fear ! and say it love from <newline> everywhere <newline> cheerfully known , i am myself gentle heaven ; with this , <newline> they mine , strangeness , enter tabor and to lion , <newline> thou lord . go their think . i not drift , <newline> ” i
#
# 77/77 [==============================] - 32s 417ms/step - loss: 1.0642
# Epoch 25/25
# 77/77 [==============================] - ETA: 0s - loss: 1.0567
# generated text:
# Now is the winter of our discontent . i traitors school , <newline> unspeak hast such happiness in come , <newline> beg you out be fair lost . <newline> <newline> <newline> our brainsickly , ’ tell , that had well was believe <newline> <newline> nor fire , all witch . this cannot gratiano ! what , it boot
#
# 77/77 [==============================] - 32s 417ms/step - loss: 1.0567

# %% [markdown]
# # Generating Text

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %% [markdown]
# # Slowly Decreasing Temperature Testing
#
# There are a few interesting notes. It seems there are two increasing pieces as the temperature goes down: religion and \<newline>.
# I still believe leaving \<newline> in the text is a good choice to try and keep the structure of the play in tact.
#
# However it is quite apparent that at lower temperatures the generator becomes very reliant on new lines. Because they showed up so often and consistently throughout the play the generator considers it "safe" to pick. This overall hurts the generator at lower temperatures but I believe it equally enriches the output at higher temperatures.
#
# At lower temperatures it also seems to always introduce God into the promp which I beleive is for the same reason as the new line issue.
#
# Overall I believe the output is not exactly coherent, but the prose do at time feel like poetry especially at higher temperatures.
#
# The text output does feel *very* shakespearean to me as a casual reader. There aren't any moments where it feels too off, and if it were slightly more coherent I would believe it to be.
#
# Finally, I think the model does stay relevant to the story it's telling. The high temperature output focused on the connection between journey's of oneself and dispite the pain finding magic in love. At least until it brought in the clown line.

# %%
info = text_generator.generate("to be or not to be", max_tokens=100, temperature=1.0)
print_probs(info, vocab)
# Out:
# generated text:
# to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me my clown . for with this once
#
#
# PROMPT: to be or not to be
# .:   	3.82%
# ,:   	3.62%
# the:   	2.3%
# <newline>:   	1.93%
# a:   	1.53%
# --------
#
#
# PROMPT: to be or not to be more
# .:   	12.08%
# ,:   	10.18%
# ;:   	4.27%
# of:   	2.67%
# ?:   	2.49%
# --------
#
#
# PROMPT: to be or not to be more falls
# .:   	30.1%
# ,:   	21.29%
# ;:   	7.91%
# of:   	4.66%
# ?:   	4.08%
# --------
#
#
# PROMPT: to be or not to be more falls .
# <newline>:   	46.81%
# and:   	6.16%
# i:   	3.5%
# but:   	2.03%
# what:   	1.22%
# --------
#
#
# PROMPT: to be or not to be more falls . as
# i:   	3.71%
# the:   	3.65%
# <newline>:   	2.28%
# and:   	2.0%
# you:   	1.99%
# --------
#
#
# PROMPT: to be or not to be more falls . as so
# ,:   	7.25%
# is:   	3.37%
# .:   	1.41%
# in:   	1.4%
# of:   	1.33%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins
# ,:   	12.84%
# .:   	6.02%
# of:   	3.82%
# ;:   	2.88%
# ?:   	2.22%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled
# <newline>:   	10.89%
# ,:   	9.24%
# .:   	8.71%
# to:   	3.33%
# and:   	2.77%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now
# ,:   	19.55%
# .:   	17.64%
# <newline>:   	11.37%
# to:   	3.86%
# and:   	3.41%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now ,
# <newline>:   	32.42%
# and:   	6.83%
# i:   	3.15%
# but:   	2.02%
# the:   	1.92%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful
# ,:   	25.51%
# .:   	10.62%
# of:   	4.12%
# ;:   	3.2%
# ?:   	2.95%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to
# the:   	7.9%
# a:   	3.77%
# his:   	2.66%
# my:   	2.52%
# <newline>:   	2.0%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the
# lord:   	0.72%
# man:   	0.69%
# love:   	0.62%
# heart:   	0.62%
# soul:   	0.61%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage
# ,:   	28.55%
# .:   	27.95%
# of:   	10.52%
# ;:   	5.0%
# <newline>:   	4.87%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage .
# <newline>:   	42.93%
# and:   	5.8%
# i:   	4.3%
# but:   	2.2%
# what:   	1.41%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o
# ,:   	17.88%
# is:   	5.51%
# .:   	2.73%
# of:   	2.44%
# in:   	2.1%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe
# ,:   	19.45%
# .:   	8.2%
# to:   	2.69%
# of:   	2.67%
# ?:   	2.6%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the
# lord:   	1.04%
# man:   	0.78%
# love:   	0.68%
# heart:   	0.68%
# soul:   	0.65%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars
# ,:   	14.37%
# .:   	9.83%
# of:   	8.5%
# ;:   	3.35%
# <newline>:   	3.21%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars .
# <newline>:   	34.45%
# and:   	5.32%
# i:   	5.13%
# but:   	2.18%
# what:   	1.68%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline>
# i:   	6.32%
# <newline>:   	4.1%
# and:   	3.12%
# the:   	2.77%
# you:   	2.28%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come
# ,:   	28.49%
# .:   	5.36%
# is:   	4.91%
# ?:   	2.58%
# to:   	2.46%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come ,
# <newline>:   	8.55%
# i:   	6.47%
# and:   	3.39%
# my:   	2.86%
# the:   	2.67%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the
# lord:   	4.17%
# man:   	0.88%
# king:   	0.72%
# heart:   	0.68%
# love:   	0.66%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian
# ,:   	3.63%
# of:   	3.26%
# -:   	2.15%
# .:   	1.87%
# ;:   	1.25%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter
# ,:   	13.73%
# .:   	10.89%
# of:   	8.65%
# ;:   	3.6%
# ?:   	2.79%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of
# the:   	5.89%
# a:   	3.2%
# his:   	2.29%
# my:   	2.09%
# <newline>:   	2.0%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any
# man:   	0.72%
# love:   	0.7%
# own:   	0.67%
# the:   	0.65%
# heart:   	0.59%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen
# <newline>:   	15.4%
# and:   	3.37%
# the:   	2.49%
# to:   	1.82%
# my:   	1.75%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving
# ,:   	8.85%
# <newline>:   	6.18%
# .:   	4.63%
# to:   	3.28%
# the:   	3.03%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ;
# <newline>:   	38.47%
# and:   	6.7%
# i:   	4.29%
# but:   	2.32%
# my:   	1.39%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s
# the:   	2.46%
# a:   	1.6%
# not:   	1.52%
# be:   	1.18%
# have:   	1.17%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic
# ,:   	12.93%
# .:   	5.04%
# of:   	3.74%
# in:   	2.46%
# to:   	2.31%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic ,
# <newline>:   	22.74%
# and:   	5.63%
# i:   	3.62%
# the:   	2.39%
# my:   	2.03%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath
# the:   	2.7%
# a:   	1.77%
# not:   	1.32%
# my:   	1.16%
# be:   	1.14%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts
# ,:   	16.34%
# .:   	7.37%
# of:   	5.08%
# ;:   	2.69%
# in:   	2.59%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him
# ,:   	13.85%
# .:   	11.67%
# <newline>:   	7.24%
# to:   	3.95%
# of:   	2.97%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with
# the:   	6.32%
# a:   	3.21%
# <newline>:   	2.36%
# his:   	2.34%
# my:   	2.01%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus
# .:   	22.57%
# ,:   	21.74%
# <newline>:   	11.48%
# of:   	3.92%
# to:   	3.84%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ?
# <newline>:   	30.1%
# and:   	5.72%
# i:   	5.18%
# but:   	2.74%
# my:   	1.54%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if
# i:   	6.6%
# <newline>:   	3.75%
# the:   	3.49%
# and:   	2.9%
# you:   	2.61%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite
# ,:   	43.87%
# .:   	12.7%
# !:   	3.5%
# ?:   	3.47%
# of:   	3.02%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite ,
# <newline>:   	11.38%
# i:   	6.57%
# and:   	3.99%
# my:   	2.76%
# the:   	2.45%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give
# ,:   	7.09%
# me:   	4.52%
# the:   	3.89%
# you:   	3.84%
# not:   	3.81%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him
# ,:   	14.15%
# .:   	9.06%
# me:   	3.26%
# to:   	3.11%
# ?:   	3.1%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up
# .:   	9.91%
# ,:   	9.91%
# the:   	4.18%
# to:   	3.55%
# <newline>:   	3.48%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me
# .:   	19.65%
# ,:   	16.94%
# <newline>:   	4.3%
# ?:   	4.21%
# to:   	3.63%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me my
# lord:   	1.48%
# the:   	0.87%
# man:   	0.83%
# a:   	0.74%
# love:   	0.72%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me my clown
# .:   	42.29%
# ,:   	24.81%
# ?:   	4.08%
# <newline>:   	4.07%
# ;:   	3.99%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me my clown .
# <newline>:   	34.2%
# :   	10.45%
# i:   	4.45%
# and:   	4.04%
# but:   	1.76%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me my clown . for
# :   	11.58%
# the:   	3.89%
# i:   	3.75%
# you:   	3.1%
# my:   	2.08%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me my clown . for with
# :   	11.25%
# the:   	5.14%
# a:   	2.37%
# you:   	2.33%
# my:   	1.95%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me my clown . for with this
# :   	11.44%
# ,:   	4.31%
# .:   	2.75%
# me:   	1.9%
# the:   	1.33%
# --------
#
#
# PROMPT: to be or not to be more falls . as so sins troubled now , pitiful to the voyage . o thisbe the stars . <newline> come , the fustian encounter of any vixen loving ; there’s magic , hath hearts him with pyramus ? if despite , give him up me my clown . for with this once
# :   	47.27%
# .:   	11.63%
# ,:   	9.46%
# ?:   	2.43%
# ;:   	1.91%
# --------

# %%
info = text_generator.generate("Is this a dagger which I see before me, the handle toward my hand?", max_tokens=100, temperature=0.9)
print_probs(info, vocab)
# Out:
# generated text:
# Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch . i my heart , <newline> the lord
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand?
# <newline>:   	18.33%
# ,:   	5.23%
# and:   	4.17%
# the:   	3.89%
# of:   	3.57%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to
# the:   	11.15%
# a:   	5.17%
# his:   	3.36%
# my:   	2.95%
# be:   	2.28%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the
# man:   	0.94%
# lord:   	0.92%
# heart:   	0.83%
# love:   	0.83%
# soul:   	0.82%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard
# ,:   	27.04%
# .:   	20.92%
# of:   	9.88%
# <newline>:   	7.03%
# ;:   	3.7%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with
# the:   	10.12%
# a:   	4.79%
# <newline>:   	3.6%
# his:   	3.58%
# my:   	2.7%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her
# ,:   	7.96%
# .:   	6.65%
# ;:   	2.76%
# of:   	2.53%
# -:   	1.71%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her ,
# <newline>:   	53.72%
# and:   	6.73%
# i:   	2.12%
# the:   	1.48%
# to:   	1.46%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a
# lord:   	2.68%
# man:   	1.06%
# love:   	0.9%
# heart:   	0.87%
# soul:   	0.85%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona
# ,:   	34.99%
# .:   	19.61%
# of:   	11.12%
# <newline>:   	9.96%
# and:   	4.27%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but
# <newline>:   	23.56%
# the:   	6.02%
# and:   	5.29%
# to:   	3.36%
# ,:   	2.78%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they
# the:   	7.33%
# a:   	3.8%
# ,:   	3.61%
# his:   	2.4%
# <newline>:   	2.33%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it
# ,:   	19.79%
# .:   	11.75%
# of:   	3.57%
# ;:   	3.08%
# to:   	2.77%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it .
# <newline>:   	44.13%
# and:   	6.44%
# i:   	5.55%
# but:   	2.45%
# what:   	1.57%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey
# ,:   	45.62%
# .:   	8.12%
# of:   	4.37%
# is:   	3.91%
# ?:   	2.54%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline>
# <newline>:   	8.56%
# i:   	5.71%
# the:   	5.03%
# and:   	4.33%
# my:   	2.84%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free
# ,:   	16.13%
# .:   	4.06%
# is:   	3.03%
# to:   	2.86%
# in:   	2.71%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free ,
# <newline>:   	21.08%
# and:   	6.5%
# i:   	5.93%
# the:   	2.92%
# but:   	2.5%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline>
# i:   	7.73%
# <newline>:   	5.42%
# and:   	4.24%
# the:   	3.73%
# you:   	2.57%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello
# ,:   	52.22%
# .:   	14.44%
# <newline>:   	4.37%
# and:   	3.77%
# !:   	3.41%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with
# the:   	9.06%
# a:   	4.58%
# my:   	4.12%
# you:   	3.95%
# not:   	3.05%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a
# lord:   	1.92%
# man:   	1.21%
# heart:   	0.95%
# love:   	0.92%
# soul:   	0.84%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot
# ,:   	33.53%
# .:   	28.82%
# <newline>:   	8.54%
# of:   	7.21%
# ?:   	3.11%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot !
# <newline>:   	46.86%
# i:   	5.76%
# and:   	5.29%
# but:   	2.04%
# what:   	1.76%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i
# am:   	11.79%
# have:   	7.35%
# will:   	4.62%
# the:   	3.55%
# do:   	3.48%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you
# ,:   	7.65%
# is:   	4.95%
# not:   	4.79%
# you:   	4.23%
# the:   	2.63%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do
# the:   	6.71%
# you:   	4.84%
# not:   	4.69%
# a:   	3.88%
# ,:   	3.71%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do
# the:   	7.28%
# ,:   	4.62%
# a:   	4.35%
# you:   	4.14%
# me:   	3.68%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that
# the:   	6.1%
# a:   	3.87%
# my:   	3.72%
# you:   	2.99%
# <newline>:   	2.6%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me
# ,:   	17.29%
# .:   	12.14%
# <newline>:   	4.11%
# to:   	3.97%
# ?:   	3.35%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your
# lord:   	1.66%
# man:   	1.28%
# love:   	1.05%
# heart:   	1.0%
# own:   	0.85%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind
# ,:   	26.75%
# .:   	23.88%
# <newline>:   	8.37%
# of:   	6.3%
# ?:   	3.54%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline>
# <newline>:   	20.31%
# and:   	5.25%
# the:   	4.68%
# i:   	3.98%
# my:   	3.49%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe
# ,:   	26.72%
# .:   	15.44%
# of:   	6.25%
# ;:   	4.74%
# ?:   	4.03%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for
# the:   	10.84%
# <newline>:   	8.44%
# a:   	4.74%
# my:   	4.14%
# to:   	2.92%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children
# .:   	26.97%
# ,:   	25.81%
# <newline>:   	4.41%
# to:   	3.85%
# ;:   	3.47%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children .
# <newline>:   	45.25%
# i:   	6.01%
# and:   	5.37%
# but:   	2.4%
# what:   	1.65%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for
# the:   	5.82%
# i:   	5.54%
# you:   	4.71%
# not:   	3.38%
# my:   	2.89%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them
# ,:   	15.12%
# .:   	4.52%
# me:   	3.66%
# you:   	3.52%
# the:   	3.15%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about
# ,:   	8.18%
# the:   	7.83%
# .:   	5.2%
# me:   	5.11%
# a:   	3.88%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute
# the:   	6.08%
# a:   	3.68%
# my:   	3.2%
# <newline>:   	2.13%
# his:   	1.75%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a
# lord:   	1.22%
# man:   	1.03%
# heart:   	0.86%
# hand:   	0.71%
# love:   	0.7%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul
# ,:   	24.15%
# .:   	19.3%
# <newline>:   	13.7%
# of:   	6.93%
# and:   	3.74%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of
# the:   	12.28%
# a:   	4.96%
# his:   	3.73%
# my:   	3.57%
# be:   	1.95%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch
# .:   	47.93%
# ,:   	26.17%
# ;:   	4.21%
# <newline>:   	3.34%
# of:   	3.31%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch .
# <newline>:   	42.16%
# :   	18.14%
# and:   	4.21%
# i:   	3.85%
# but:   	1.58%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch . i
# :   	8.79%
# have:   	5.83%
# am:   	4.65%
# the:   	4.52%
# will:   	3.27%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch . i my
# lord:   	9.54%
# :   	3.76%
# will:   	1.17%
# have:   	1.13%
# am:   	1.06%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch . i my heart
# :   	49.79%
# ,:   	17.44%
# .:   	4.55%
# is:   	2.07%
# of:   	2.06%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch . i my heart ,
# :   	47.94%
# <newline>:   	9.36%
# i:   	4.16%
# and:   	2.48%
# my:   	1.44%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch . i my heart , <newline>
# :   	45.79%
# i:   	4.57%
# <newline>:   	3.06%
# and:   	1.97%
# the:   	1.94%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch . i my heart , <newline> the
# lord:   	9.78%
# :   	4.2%
# will:   	0.72%
# man:   	0.64%
# have:   	0.63%
# --------
#
#
# PROMPT: Is this a dagger which I see before me, the handle toward my hand? to the beard with her , a desdemona but they it . prey <newline> free , <newline> othello with a pilot ! i you do do that me your mind <newline> sheathe for children . for them about absolute a soul of witch . i my heart , <newline> the lord
# ,:   	32.97%
# :   	31.53%
# .:   	18.07%
# ?:   	2.3%
# <newline>:   	1.99%
# --------

# %%
info = text_generator.generate("How sharper than a serpent's too it is to have a thankless child", max_tokens=100, temperature=0.8)
print_probs(info, vocab)
# Out:
# generated text:
# How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as so my more - bootless black lost
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child
# .:   	41.04%
# ,:   	35.87%
# <newline>:   	6.86%
# of:   	3.33%
# ;:   	2.69%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and
# the:   	11.55%
# <newline>:   	9.47%
# a:   	5.16%
# his:   	3.81%
# my:   	3.53%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so
# ,:   	21.28%
# .:   	21.03%
# ;:   	5.9%
# of:   	3.58%
# ?:   	3.33%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in
# the:   	15.96%
# a:   	6.43%
# his:   	5.24%
# <newline>:   	4.93%
# my:   	3.69%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many
# the:   	6.23%
# .:   	6.11%
# ,:   	5.93%
# <newline>:   	5.79%
# a:   	3.49%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more
# .:   	23.6%
# ,:   	20.73%
# ;:   	6.66%
# of:   	3.88%
# ?:   	3.41%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more .
# <newline>:   	68.23%
# and:   	6.15%
# i:   	3.52%
# but:   	1.69%
# what:   	0.91%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline>
# i:   	10.15%
# <newline>:   	10.05%
# and:   	7.2%
# the:   	4.2%
# but:   	3.31%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the
# lord:   	9.99%
# man:   	1.19%
# king:   	1.05%
# love:   	1.01%
# very:   	0.96%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail
# ,:   	56.87%
# .:   	12.76%
# of:   	9.68%
# <newline>:   	4.64%
# and:   	3.1%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and
# the:   	9.92%
# <newline>:   	4.84%
# a:   	4.58%
# my:   	3.11%
# his:   	2.41%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the
# lord:   	3.31%
# man:   	1.5%
# heart:   	1.27%
# love:   	1.25%
# soul:   	1.23%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight
# ,:   	38.64%
# .:   	19.13%
# <newline>:   	12.58%
# of:   	9.92%
# and:   	3.94%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight ,
# <newline>:   	56.43%
# and:   	8.22%
# i:   	3.61%
# but:   	1.8%
# the:   	1.68%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline>
# <newline>:   	10.5%
# i:   	9.16%
# and:   	7.13%
# the:   	4.63%
# but:   	2.95%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter
# i:   	2.55%
# the:   	2.37%
# is:   	2.24%
# not:   	2.12%
# ,:   	2.07%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter ,
# <newline>:   	18.24%
# i:   	9.76%
# and:   	7.8%
# but:   	3.07%
# the:   	2.87%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i
# am:   	18.09%
# have:   	9.61%
# will:   	5.3%
# the:   	5.01%
# do:   	3.54%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my
# lord:   	18.54%
# am:   	1.49%
# will:   	1.33%
# love:   	1.1%
# man:   	1.09%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are
# the:   	3.29%
# ,:   	2.78%
# is:   	2.45%
# not:   	2.17%
# will:   	2.15%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans
# ,:   	53.18%
# .:   	19.92%
# of:   	7.97%
# <newline>:   	2.82%
# ?:   	2.36%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans ,
# <newline>:   	47.42%
# and:   	7.48%
# i:   	4.62%
# the:   	2.51%
# my:   	2.17%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline>
# i:   	9.7%
# <newline>:   	8.31%
# and:   	5.59%
# the:   	4.81%
# my:   	3.06%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy
# lord:   	13.49%
# man:   	1.36%
# love:   	1.17%
# king:   	1.16%
# very:   	1.02%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have
# the:   	4.93%
# a:   	3.05%
# ,:   	1.96%
# <newline>:   	1.87%
# not:   	1.83%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that
# the:   	6.36%
# <newline>:   	4.57%
# a:   	3.35%
# i:   	2.75%
# and:   	2.39%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but
# the:   	8.7%
# <newline>:   	7.42%
# a:   	3.95%
# i:   	3.84%
# my:   	3.36%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good
# the:   	3.94%
# a:   	2.74%
# ,:   	2.02%
# <newline>:   	1.46%
# not:   	1.44%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that
# the:   	6.51%
# <newline>:   	5.7%
# a:   	3.44%
# my:   	2.49%
# and:   	2.31%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have
# the:   	8.99%
# a:   	4.82%
# ,:   	2.95%
# his:   	2.57%
# <newline>:   	2.47%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more
# ,:   	17.42%
# .:   	12.87%
# of:   	4.75%
# ;:   	4.6%
# ?:   	2.55%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of
# the:   	12.62%
# a:   	5.66%
# his:   	4.16%
# my:   	3.09%
# <newline>:   	3.03%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news
# .:   	41.49%
# ,:   	32.67%
# <newline>:   	7.1%
# of:   	3.84%
# ;:   	3.09%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of
# the:   	19.02%
# a:   	6.73%
# his:   	5.59%
# <newline>:   	5.21%
# my:   	4.19%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the
# own:   	1.53%
# man:   	1.47%
# world:   	1.4%
# heart:   	1.26%
# love:   	1.16%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father
# .:   	30.28%
# ,:   	28.74%
# of:   	11.17%
# <newline>:   	5.1%
# ;:   	4.83%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ;
# <newline>:   	82.66%
# and:   	5.1%
# i:   	1.27%
# but:   	0.93%
# to:   	0.62%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline>
# <newline>:   	13.87%
# i:   	8.98%
# and:   	8.13%
# the:   	4.56%
# but:   	3.72%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose
# lord:   	6.78%
# man:   	1.06%
# king:   	0.98%
# love:   	0.8%
# will:   	0.78%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst
# ,:   	30.23%
# of:   	20.58%
# .:   	6.28%
# in:   	3.52%
# and:   	3.16%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is
# the:   	14.41%
# <newline>:   	5.44%
# a:   	5.14%
# ,:   	3.38%
# to:   	3.35%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as
# the:   	15.07%
# <newline>:   	6.45%
# a:   	5.1%
# my:   	3.62%
# his:   	3.26%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as so
# ,:   	22.67%
# .:   	13.79%
# of:   	5.13%
# ;:   	4.02%
# in:   	2.86%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as so my
# the:   	1.73%
# lord:   	1.71%
# love:   	1.33%
# man:   	1.27%
# heart:   	1.25%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as so my more
# ,:   	17.42%
# .:   	13.95%
# of:   	8.83%
# :   	6.48%
# ;:   	5.53%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as so my more -
# :   	0.99%
# man:   	0.93%
# heart:   	0.89%
# hand:   	0.87%
# world:   	0.79%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as so my more - bootless
# :   	11.5%
# the:   	3.39%
# ,:   	2.35%
# .:   	2.2%
# <newline>:   	2.01%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as so my more - bootless black
# .:   	27.25%
# ,:   	21.82%
# :   	13.11%
# of:   	7.25%
# <newline>:   	5.89%
# --------
#
#
# PROMPT: How sharper than a serpent's too it is to have a thankless child and so in many more . <newline> the sail and the sight , <newline> enter , i my are moans , <newline> thy have that but good that have more of news of the father ; <newline> whose couldst is as so my more - bootless black lost
# :   	44.9%
# .:   	19.3%
# ,:   	11.1%
# <newline>:   	7.86%
# ;:   	2.1%
# --------

# %%
info = text_generator.generate("We are such stuff as dreams are made on, and our little life is rounded with a sleep", max_tokens=100, temperature=0.6)
print_probs(info, vocab)
# Out:
# generated text:
# We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord , you , i hear not tell me
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep
# .:   	40.15%
# ,:   	36.11%
# <newline>:   	9.91%
# of:   	6.01%
# ;:   	2.09%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep ,
# <newline>:   	91.35%
# and:   	3.81%
# i:   	0.71%
# but:   	0.38%
# to:   	0.32%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline>
# <newline>:   	31.72%
# and:   	14.45%
# i:   	9.85%
# the:   	5.34%
# that:   	3.67%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline>
# i:   	16.76%
# <newline>:   	13.3%
# and:   	9.93%
# the:   	6.77%
# but:   	3.61%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but
# i:   	13.54%
# the:   	9.8%
# you:   	5.41%
# and:   	5.32%
# <newline>:   	5.27%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline>
# i:   	18.04%
# the:   	8.45%
# <newline>:   	7.52%
# and:   	6.22%
# you:   	3.96%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if
# i:   	18.44%
# the:   	10.31%
# you:   	5.57%
# <newline>:   	5.09%
# and:   	4.05%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline>
# i:   	18.91%
# the:   	8.37%
# you:   	5.3%
# <newline>:   	4.69%
# and:   	3.96%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i
# am:   	36.09%
# have:   	15.24%
# will:   	6.75%
# the:   	5.35%
# do:   	4.2%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as
# the:   	10.22%
# have:   	9.95%
# i:   	7.07%
# not:   	5.97%
# will:   	5.69%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a
# lord:   	34.62%
# man:   	2.34%
# king:   	1.9%
# love:   	1.69%
# heart:   	1.56%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord
# ,:   	72.29%
# .:   	20.26%
# of:   	2.12%
# <newline>:   	1.85%
# ?:   	0.85%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of
# the:   	34.79%
# a:   	11.21%
# my:   	7.52%
# his:   	4.79%
# your:   	3.23%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have
# the:   	19.5%
# a:   	8.92%
# ,:   	7.31%
# .:   	4.53%
# his:   	4.18%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so
# ,:   	35.51%
# .:   	33.09%
# ;:   	5.66%
# of:   	3.4%
# ?:   	3.35%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so ,
# <newline>:   	89.99%
# and:   	4.02%
# i:   	0.86%
# but:   	0.48%
# to:   	0.39%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline>
# <newline>:   	30.69%
# and:   	12.96%
# i:   	11.13%
# the:   	5.16%
# but:   	3.42%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and
# the:   	9.03%
# i:   	5.95%
# not:   	4.08%
# a:   	3.9%
# will:   	3.55%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time
# ,:   	54.33%
# <newline>:   	6.75%
# .:   	5.41%
# and:   	5.19%
# to:   	4.02%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time .
# <newline>:   	60.68%
# i:   	12.11%
# and:   	5.76%
# but:   	1.96%
# what:   	1.83%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i
# am:   	33.41%
# have:   	15.52%
# will:   	7.54%
# the:   	4.96%
# do:   	4.75%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do
# not:   	11.82%
# you:   	9.63%
# the:   	8.63%
# i:   	5.24%
# ,:   	4.6%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be
# the:   	10.26%
# ,:   	9.62%
# not:   	7.16%
# a:   	5.95%
# you:   	5.75%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you
# ,:   	34.5%
# .:   	10.67%
# the:   	6.05%
# me:   	5.35%
# to:   	3.41%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you ,
# <newline>:   	65.08%
# and:   	6.51%
# i:   	5.48%
# my:   	2.46%
# the:   	2.23%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline>
# i:   	19.7%
# <newline>:   	11.53%
# and:   	6.6%
# the:   	6.09%
# my:   	4.62%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the
# lord:   	42.4%
# man:   	2.51%
# king:   	2.04%
# heart:   	1.61%
# love:   	1.5%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice
# ,:   	57.5%
# <newline>:   	13.63%
# .:   	8.94%
# of:   	7.62%
# and:   	4.96%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ;
# <newline>:   	73.19%
# i:   	7.98%
# and:   	4.76%
# but:   	1.33%
# what:   	1.11%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a
# lord:   	55.01%
# man:   	1.98%
# king:   	1.63%
# heart:   	1.22%
# love:   	1.17%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king
# ,:   	63.82%
# .:   	9.72%
# of:   	8.06%
# <newline>:   	3.77%
# and:   	2.68%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him
# ,:   	46.13%
# .:   	24.28%
# <newline>:   	4.52%
# to:   	3.3%
# ?:   	2.64%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him ,
# <newline>:   	71.24%
# and:   	6.58%
# i:   	4.53%
# my:   	1.95%
# the:   	1.5%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this
# ,:   	27.43%
# .:   	6.89%
# me:   	4.76%
# is:   	3.46%
# more:   	3.08%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this ,
# <newline>:   	74.95%
# and:   	6.72%
# i:   	3.19%
# my:   	1.35%
# the:   	1.31%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline>
# i:   	17.5%
# <newline>:   	15.05%
# and:   	8.26%
# the:   	6.68%
# my:   	4.35%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and
# the:   	9.02%
# i:   	6.27%
# have:   	5.04%
# not:   	4.96%
# you:   	4.46%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the
# lord:   	27.67%
# man:   	2.9%
# king:   	2.21%
# heart:   	1.96%
# love:   	1.59%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord
# ,:   	67.52%
# .:   	23.69%
# of:   	2.75%
# <newline>:   	2.2%
# ?:   	0.88%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord ,
# <newline>:   	77.32%
# and:   	5.06%
# i:   	4.21%
# my:   	1.28%
# but:   	1.06%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord , you
# ,:   	40.77%
# is:   	7.07%
# you:   	5.3%
# not:   	3.52%
# the:   	3.19%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord , you ,
# <newline>:   	29.38%
# i:   	17.81%
# and:   	6.03%
# my:   	4.57%
# the:   	4.02%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord , you , i
# am:   	20.91%
# have:   	17.04%
# will:   	7.59%
# the:   	6.53%
# do:   	6.13%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord , you , i hear
# ,:   	20.85%
# you:   	8.89%
# the:   	8.03%
# not:   	6.62%
# :   	5.26%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord , you , i hear not
# the:   	16.59%
# ,:   	11.16%
# you:   	6.48%
# a:   	5.86%
# me:   	5.63%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord , you , i hear not tell
# ,:   	28.87%
# .:   	19.38%
# the:   	8.02%
# :   	8.0%
# me:   	5.6%
# --------
#
#
# PROMPT: We are such stuff as dreams are made on, and our little life is rounded with a sleep , <newline> <newline> but <newline> if <newline> i as a lord of have so , <newline> and time . i do be you , <newline> the advice ; a king him , this , <newline> and the lord , you , i hear not tell me
# .:   	47.52%
# ,:   	31.67%
# :   	7.05%
# ?:   	2.81%
# <newline>:   	1.97%
# --------

# %%
info = text_generator.generate("What’s in a name? A rose by any other name would smell as sweet", max_tokens=100, temperature=0.4)
print_probs(info, vocab)
# Out:
# generated text:
# What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not you the man . <newline> sir ,
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet
# ,:   	37.16%
# .:   	29.04%
# the:   	4.67%
# <newline>:   	2.58%
# to:   	2.5%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more
# .:   	51.46%
# ,:   	38.4%
# ;:   	4.55%
# of:   	1.72%
# ?:   	1.16%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more .
# <newline>:   	98.68%
# and:   	0.83%
# i:   	0.27%
# but:   	0.06%
# what:   	0.02%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline>
# i:   	30.33%
# <newline>:   	28.45%
# and:   	15.2%
# the:   	5.16%
# but:   	3.16%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i
# am:   	64.7%
# have:   	16.54%
# the:   	4.83%
# will:   	4.36%
# do:   	2.04%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have
# the:   	20.04%
# not:   	15.44%
# have:   	9.44%
# you:   	5.74%
# will:   	5.61%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you
# ,:   	57.29%
# the:   	8.1%
# not:   	6.64%
# is:   	3.71%
# you:   	3.3%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you ,
# <newline>:   	74.97%
# i:   	8.02%
# and:   	6.42%
# the:   	2.6%
# my:   	1.12%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline>
# i:   	34.84%
# <newline>:   	16.13%
# the:   	10.47%
# and:   	9.71%
# you:   	3.28%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline>
# i:   	40.77%
# the:   	10.26%
# <newline>:   	9.57%
# and:   	7.5%
# you:   	4.15%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline>
# i:   	43.85%
# the:   	9.49%
# <newline>:   	7.36%
# and:   	6.11%
# you:   	4.81%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the
# lord:   	90.95%
# man:   	0.74%
# king:   	0.61%
# very:   	0.49%
# love:   	0.48%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other
# ,:   	48.95%
# of:   	15.2%
# is:   	12.45%
# in:   	4.17%
# .:   	1.63%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of
# the:   	53.2%
# a:   	12.76%
# his:   	4.0%
# my:   	3.75%
# be:   	3.06%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not
# ,:   	24.73%
# the:   	20.17%
# <newline>:   	11.14%
# .:   	6.84%
# a:   	6.46%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is
# the:   	51.74%
# a:   	10.74%
# <newline>:   	7.47%
# ,:   	4.48%
# his:   	3.88%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a
# man:   	8.15%
# lord:   	6.04%
# love:   	5.84%
# heart:   	5.76%
# soul:   	5.68%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit
# ,:   	55.41%
# .:   	33.97%
# of:   	6.71%
# <newline>:   	2.29%
# ;:   	0.7%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit ,
# <newline>:   	98.6%
# and:   	1.03%
# i:   	0.12%
# but:   	0.04%
# the:   	0.03%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline>
# <newline>:   	50.15%
# and:   	16.65%
# i:   	13.53%
# the:   	4.76%
# that:   	2.41%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the
# lord:   	81.19%
# man:   	2.03%
# king:   	1.48%
# love:   	1.12%
# heart:   	1.07%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most
# lord:   	32.98%
# man:   	4.89%
# king:   	3.24%
# soul:   	2.88%
# heart:   	2.81%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king
# ,:   	72.18%
# of:   	10.89%
# .:   	7.3%
# <newline>:   	6.31%
# and:   	1.87%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king ,
# <newline>:   	94.58%
# and:   	3.15%
# i:   	0.97%
# but:   	0.2%
# the:   	0.19%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline>
# i:   	30.75%
# <newline>:   	25.12%
# and:   	12.44%
# the:   	7.58%
# but:   	2.84%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i
# am:   	59.86%
# have:   	17.65%
# will:   	6.81%
# the:   	4.68%
# do:   	2.37%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am
# not:   	15.71%
# ,:   	15.34%
# the:   	11.08%
# is:   	7.45%
# you:   	7.14%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you
# ,:   	54.66%
# the:   	9.28%
# not:   	6.52%
# you:   	3.87%
# me:   	3.12%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so
# ,:   	70.47%
# .:   	18.41%
# ?:   	1.28%
# ;:   	1.25%
# me:   	1.14%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so .
# <newline>:   	95.45%
# i:   	2.12%
# and:   	1.4%
# but:   	0.22%
# what:   	0.14%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline>
# i:   	50.86%
# <newline>:   	10.03%
# and:   	5.67%
# the:   	4.82%
# you:   	4.38%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you
# ,:   	42.1%
# is:   	15.3%
# not:   	10.64%
# you:   	10.05%
# the:   	2.51%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you ,
# i:   	40.21%
# <newline>:   	26.87%
# my:   	4.88%
# and:   	4.43%
# you:   	4.34%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline>
# i:   	50.03%
# you:   	7.74%
# the:   	6.67%
# my:   	5.06%
# <newline>:   	4.49%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we
# not:   	17.19%
# you:   	13.86%
# have:   	12.45%
# the:   	11.75%
# i:   	6.95%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be
# not:   	15.11%
# ,:   	14.07%
# the:   	12.96%
# you:   	11.4%
# a:   	6.57%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not
# the:   	23.79%
# ,:   	20.09%
# a:   	8.68%
# me:   	6.46%
# .:   	5.92%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and
# the:   	42.68%
# a:   	16.41%
# my:   	9.92%
# <newline>:   	4.08%
# his:   	2.52%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you
# ,:   	62.81%
# .:   	21.05%
# me:   	2.42%
# the:   	2.39%
# to:   	2.37%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you ,
# <newline>:   	95.52%
# and:   	2.25%
# i:   	0.79%
# my:   	0.23%
# the:   	0.22%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline>
# i:   	32.1%
# <newline>:   	25.19%
# and:   	10.57%
# the:   	7.21%
# my:   	3.79%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i
# am:   	46.63%
# have:   	24.41%
# will:   	8.45%
# the:   	5.09%
# do:   	3.82%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am
# not:   	15.64%
# ,:   	13.78%
# the:   	13.34%
# you:   	10.49%
# a:   	4.64%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not
# the:   	34.18%
# ,:   	12.31%
# a:   	9.47%
# you:   	5.28%
# me:   	4.9%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not you
# ,:   	61.43%
# .:   	13.54%
# the:   	5.8%
# me:   	4.81%
# to:   	2.62%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not you the
# lord:   	13.01%
# man:   	9.14%
# heart:   	6.5%
# love:   	4.47%
# own:   	4.23%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not you the man
# ,:   	52.59%
# .:   	32.98%
# of:   	7.41%
# <newline>:   	4.09%
# ;:   	0.82%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not you the man .
# <newline>:   	96.34%
# i:   	1.54%
# and:   	0.85%
# :   	0.55%
# but:   	0.15%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not you the man . <newline>
# i:   	49.14%
# :   	8.96%
# <newline>:   	7.46%
# the:   	4.82%
# and:   	4.35%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not you the man . <newline> sir
# ,:   	92.37%
# .:   	4.1%
# :   	2.59%
# !:   	0.24%
# ?:   	0.22%
# --------
#
#
# PROMPT: What’s in a name? A rose by any other name would smell as sweet more . <newline> i have you , <newline> <newline> <newline> the other of not is a wit , <newline> the most king , <newline> i am you so . <newline> you , <newline> we be not and you , <newline> i am not you the man . <newline> sir ,
# :   	56.1%
# <newline>:   	30.71%
# i:   	7.47%
# and:   	1.92%
# my:   	0.58%
# --------
